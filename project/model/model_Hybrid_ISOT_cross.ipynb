# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import numpy as np

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3456917274646517915
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3643801600
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13105056621555415039
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
# MAX_VNUM = 20000
SEQUENCE_LENGTH = 300
EMBED_DIMENSION = 100
BATCH_SIZE = 64
K_FOLD = 5

# %%
column_names = ["lemmatized_clean_text", "labels"]
data = pd.read_csv("../Data_Preprocessing/Preprocessed_Dataset/ISOT_Preprocessed_Data.csv", encoding='utf-8', encoding_errors='ignore')[column_names]
train, test = train_test_split(data, test_size=0.2)

# %%
token = keras.preprocessing.text.Tokenizer()
token.fit_on_texts(data[column_names[0]])
vocab_size = len(token.word_index) + 2

# %%
embedding_vector = {}
f = open('glove.6B.100d.txt', encoding='utf-8')
for line in tqdm(f):
    word, coefs = line.split(maxsplit=1)
    coefs = np.fromstring(coefs, "f", sep=" ")
    embedding_vector[word] = coefs
embedding_matrix = np.zeros((vocab_size, EMBED_DIMENSION))
for word,i in tqdm(token.word_index.items()):
    embedding_value = embedding_vector.get(word)
    if embedding_value is not None:
        embedding_matrix[i] = embedding_value
# Out:
# 400000it [00:09, 42804.39it/s]
# 100%|██████████| 131653/131653 [00:00<00:00, 1598293.16it/s]

# %% [markdown]
# ### Model

# %%
def model_generator():
    model = keras.models.Sequential()
    model.add(layers.Embedding(input_dim=vocab_size, output_dim=EMBED_DIMENSION, 
                        embeddings_initializer=keras.initializers.Constant(embedding_matrix), 
                        input_length=SEQUENCE_LENGTH, trainable = False))
    model.add(layers.Permute((2, 1)))
    model.add(layers.Conv1D(128, 5, activation='relu', name="Conv1D"))
    model.add(layers.MaxPooling1D(pool_size=2, name="MaxPooling1D"))
    model.add(layers.LSTM(32, 
                        #   activation=None, 
                          name="LSTM"))
    model.add(layers.Dense(1, activation="sigmoid"))
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=[
        "accuracy",
        tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
    ])
    return model

# %%
train_x = token.texts_to_sequences(train[column_names[0]])
train_x = keras.preprocessing.sequence.pad_sequences(train_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
train_y = train[column_names[1]]

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = K_FOLD)
history = {}
loss, accuracy, precision, recall, F1 = np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD)
id = 0
epochs = 10
test_x = token.texts_to_sequences(test[column_names[0]])
test_x = keras.preprocessing.sequence.pad_sequences(test_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
test_y = test[column_names[1]]
best_model = None
best_f1 = 0
best_id = 0
for train_index, val_index in kf.split(train_x, train_y):
    training_x, training_y = train_x[train_index], train_y.iloc[train_index]
    validation_x, validation_y = train_x[val_index], train_y.iloc[val_index]
    model = model_generator()
    history[id] = model.fit(x=training_x, y=training_y, validation_data=(validation_x, validation_y),
                                               epochs=epochs, batch_size=BATCH_SIZE)
    loss[id], accuracy[id], precision[id], recall[id] = model.evaluate(x=test_x, y=test_y)
    F1[id] = 2 * (precision[id] * recall[id]) / (precision[id] + recall[id])
    if F1[id] > best_f1:
        best_model = model
        best_f1 = F1[id]
        best_id = id
    id += 1
print("Best Model: Model_{}".format(best_id))
# Out:
# Epoch 1/10
# 449/449 [==============================] - 12s 10ms/step - loss: 0.2227 - accuracy: 0.9138 - precision: 0.8977 - recall: 0.9255 - val_loss: 0.1547 - val_accuracy: 0.9478 - val_precision: 0.9264 - val_recall: 0.9677
# Epoch 2/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.1192 - accuracy: 0.9582 - precision: 0.9509 - recall: 0.9624 - val_loss: 0.1457 - val_accuracy: 0.9425 - val_precision: 0.9743 - val_recall: 0.9036
# Epoch 3/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0777 - accuracy: 0.9735 - precision: 0.9720 - recall: 0.9727 - val_loss: 0.1092 - val_accuracy: 0.9614 - val_precision: 0.9773 - val_recall: 0.9412
# Epoch 4/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0535 - accuracy: 0.9822 - precision: 0.9818 - recall: 0.9810 - val_loss: 0.1044 - val_accuracy: 0.9644 - val_precision: 0.9527 - val_recall: 0.9738
# Epoch 5/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0433 - accuracy: 0.9856 - precision: 0.9849 - recall: 0.9849 - val_loss: 0.0971 - val_accuracy: 0.9673 - val_precision: 0.9667 - val_recall: 0.9648
# Epoch 6/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0324 - accuracy: 0.9896 - precision: 0.9895 - recall: 0.9889 - val_loss: 0.1007 - val_accuracy: 0.9713 - val_precision: 0.9736 - val_recall: 0.9662
# Epoch 7/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0245 - accuracy: 0.9923 - precision: 0.9916 - recall: 0.9923 - val_loss: 0.1083 - val_accuracy: 0.9667 - val_precision: 0.9764 - val_recall: 0.9534
# Epoch 8/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0261 - accuracy: 0.9916 - precision: 0.9913 - recall: 0.9911 - val_loss: 0.1117 - val_accuracy: 0.9698 - val_precision: 0.9618 - val_recall: 0.9755
# Epoch 9/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0194 - accuracy: 0.9938 - precision: 0.9934 - recall: 0.9937 - val_loss: 0.1051 - val_accuracy: 0.9697 - val_precision: 0.9749 - val_recall: 0.9613
# Epoch 10/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0184 - accuracy: 0.9945 - precision: 0.9945 - recall: 0.9940 - val_loss: 0.1090 - val_accuracy: 0.9694 - val_precision: 0.9707 - val_recall: 0.9651
# 281/281 [==============================] - 1s 4ms/step - loss: 0.1425 - accuracy: 0.9625 - precision: 0.9583 - recall: 0.9622
# Epoch 1/10
# 449/449 [==============================] - 6s 11ms/step - loss: 0.2225 - accuracy: 0.9132 - precision_1: 0.8974 - recall_1: 0.9244 - val_loss: 0.1485 - val_accuracy: 0.9474 - val_precision_1: 0.9325 - val_recall_1: 0.9591
# Epoch 2/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.1120 - accuracy: 0.9615 - precision_1: 0.9547 - recall_1: 0.9654 - val_loss: 0.1041 - val_accuracy: 0.9651 - val_precision_1: 0.9743 - val_recall_1: 0.9519
# Epoch 3/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0662 - accuracy: 0.9785 - precision_1: 0.9767 - recall_1: 0.9785 - val_loss: 0.1281 - val_accuracy: 0.9577 - val_precision_1: 0.9327 - val_recall_1: 0.9822
# Epoch 4/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0486 - accuracy: 0.9840 - precision_1: 0.9830 - recall_1: 0.9836 - val_loss: 0.0954 - val_accuracy: 0.9710 - val_precision_1: 0.9605 - val_recall_1: 0.9796
# Epoch 5/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0336 - accuracy: 0.9893 - precision_1: 0.9890 - recall_1: 0.9887 - val_loss: 0.1079 - val_accuracy: 0.9674 - val_precision_1: 0.9761 - val_recall_1: 0.9551
# Epoch 6/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0271 - accuracy: 0.9910 - precision_1: 0.9913 - recall_1: 0.9898 - val_loss: 0.1085 - val_accuracy: 0.9681 - val_precision_1: 0.9608 - val_recall_1: 0.9729
# Epoch 7/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0240 - accuracy: 0.9921 - precision_1: 0.9925 - recall_1: 0.9911 - val_loss: 0.1041 - val_accuracy: 0.9723 - val_precision_1: 0.9659 - val_recall_1: 0.9764
# Epoch 8/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0228 - accuracy: 0.9919 - precision_1: 0.9924 - recall_1: 0.9906 - val_loss: 0.1052 - val_accuracy: 0.9695 - val_precision_1: 0.9679 - val_recall_1: 0.9682
# Epoch 9/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0185 - accuracy: 0.9941 - precision_1: 0.9941 - recall_1: 0.9935 - val_loss: 0.1672 - val_accuracy: 0.9543 - val_precision_1: 0.9859 - val_recall_1: 0.9174
# Epoch 10/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0144 - accuracy: 0.9951 - precision_1: 0.9954 - recall_1: 0.9943 - val_loss: 0.1213 - val_accuracy: 0.9708 - val_precision_1: 0.9772 - val_recall_1: 0.9612
# 281/281 [==============================] - 1s 5ms/step - loss: 0.1594 - accuracy: 0.9636 - precision_1: 0.9674 - recall_1: 0.9548
# Epoch 1/10
# 449/449 [==============================] - 7s 12ms/step - loss: 0.2220 - accuracy: 0.9116 - precision_2: 0.8974 - recall_2: 0.9207 - val_loss: 0.1486 - val_accuracy: 0.9471 - val_precision_2: 0.9354 - val_recall_2: 0.9551
# Epoch 2/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.1141 - accuracy: 0.9598 - precision_2: 0.9533 - recall_2: 0.9632 - val_loss: 0.1343 - val_accuracy: 0.9539 - val_precision_2: 0.9258 - val_recall_2: 0.9822
# Epoch 3/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0695 - accuracy: 0.9766 - precision_2: 0.9749 - recall_2: 0.9764 - val_loss: 0.1359 - val_accuracy: 0.9545 - val_precision_2: 0.9205 - val_recall_2: 0.9901
# Epoch 4/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0444 - accuracy: 0.9852 - precision_2: 0.9846 - recall_2: 0.9845 - val_loss: 0.1217 - val_accuracy: 0.9592 - val_precision_2: 0.9334 - val_recall_2: 0.9848
# Epoch 5/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0299 - accuracy: 0.9900 - precision_2: 0.9910 - recall_2: 0.9882 - val_loss: 0.1240 - val_accuracy: 0.9659 - val_precision_2: 0.9505 - val_recall_2: 0.9796
# Epoch 6/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0250 - accuracy: 0.9918 - precision_2: 0.9918 - recall_2: 0.9910 - val_loss: 0.1046 - val_accuracy: 0.9662 - val_precision_2: 0.9769 - val_recall_2: 0.9516
# Epoch 7/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0213 - accuracy: 0.9925 - precision_2: 0.9928 - recall_2: 0.9915 - val_loss: 0.1105 - val_accuracy: 0.9708 - val_precision_2: 0.9597 - val_recall_2: 0.9799
# Epoch 8/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0141 - accuracy: 0.9953 - precision_2: 0.9954 - recall_2: 0.9948 - val_loss: 0.1198 - val_accuracy: 0.9719 - val_precision_2: 0.9590 - val_recall_2: 0.9831
# Epoch 9/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0130 - accuracy: 0.9954 - precision_2: 0.9953 - recall_2: 0.9952 - val_loss: 0.1099 - val_accuracy: 0.9719 - val_precision_2: 0.9632 - val_recall_2: 0.9784
# Epoch 10/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0139 - accuracy: 0.9952 - precision_2: 0.9953 - recall_2: 0.9946 - val_loss: 0.1301 - val_accuracy: 0.9697 - val_precision_2: 0.9524 - val_recall_2: 0.9857
# 281/281 [==============================] - 1s 5ms/step - loss: 0.1586 - accuracy: 0.9614 - precision_2: 0.9417 - recall_2: 0.9785
# Epoch 1/10
# 449/449 [==============================] - 6s 11ms/step - loss: 0.2232 - accuracy: 0.9130 - precision_3: 0.9034 - recall_3: 0.9163 - val_loss: 0.1657 - val_accuracy: 0.9403 - val_precision_3: 0.9204 - val_recall_3: 0.9577
# Epoch 2/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.1165 - accuracy: 0.9599 - precision_3: 0.9542 - recall_3: 0.9626 - val_loss: 0.1155 - val_accuracy: 0.9612 - val_precision_3: 0.9565 - val_recall_3: 0.9624
# Epoch 3/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0734 - accuracy: 0.9748 - precision_3: 0.9727 - recall_3: 0.9748 - val_loss: 0.1404 - val_accuracy: 0.9511 - val_precision_3: 0.9162 - val_recall_3: 0.9881
# Epoch 4/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0497 - accuracy: 0.9837 - precision_3: 0.9838 - recall_3: 0.9822 - val_loss: 0.1655 - val_accuracy: 0.9472 - val_precision_3: 0.9074 - val_recall_3: 0.9907
# Epoch 5/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0370 - accuracy: 0.9878 - precision_3: 0.9883 - recall_3: 0.9860 - val_loss: 0.1037 - val_accuracy: 0.9687 - val_precision_3: 0.9671 - val_recall_3: 0.9674
# Epoch 6/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0266 - accuracy: 0.9915 - precision_3: 0.9911 - recall_3: 0.9911 - val_loss: 0.1035 - val_accuracy: 0.9701 - val_precision_3: 0.9743 - val_recall_3: 0.9627
# Epoch 7/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0234 - accuracy: 0.9920 - precision_3: 0.9921 - recall_3: 0.9912 - val_loss: 0.1318 - val_accuracy: 0.9667 - val_precision_3: 0.9689 - val_recall_3: 0.9612
# Epoch 8/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0195 - accuracy: 0.9933 - precision_3: 0.9935 - recall_3: 0.9926 - val_loss: 0.1146 - val_accuracy: 0.9663 - val_precision_3: 0.9705 - val_recall_3: 0.9586
# Epoch 9/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0181 - accuracy: 0.9939 - precision_3: 0.9941 - recall_3: 0.9931 - val_loss: 0.1235 - val_accuracy: 0.9695 - val_precision_3: 0.9602 - val_recall_3: 0.9767
# Epoch 10/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0143 - accuracy: 0.9948 - precision_3: 0.9946 - recall_3: 0.9946 - val_loss: 0.1190 - val_accuracy: 0.9722 - val_precision_3: 0.9676 - val_recall_3: 0.9744
# 281/281 [==============================] - 1s 5ms/step - loss: 0.1385 - accuracy: 0.9659 - precision_3: 0.9608 - recall_3: 0.9671
# Epoch 1/10
# 449/449 [==============================] - 6s 11ms/step - loss: 0.2243 - accuracy: 0.9139 - precision_4: 0.9008 - recall_4: 0.9210 - val_loss: 0.1604 - val_accuracy: 0.9439 - val_precision_4: 0.9244 - val_recall_4: 0.9625
# Epoch 2/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.1167 - accuracy: 0.9591 - precision_4: 0.9514 - recall_4: 0.9635 - val_loss: 0.1120 - val_accuracy: 0.9595 - val_precision_4: 0.9568 - val_recall_4: 0.9593
# Epoch 3/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0696 - accuracy: 0.9764 - precision_4: 0.9743 - recall_4: 0.9763 - val_loss: 0.1085 - val_accuracy: 0.9630 - val_precision_4: 0.9505 - val_recall_4: 0.9740
# Epoch 4/10
# 449/449 [==============================] - 4s 10ms/step - loss: 0.0479 - accuracy: 0.9844 - precision_4: 0.9837 - recall_4: 0.9837 - val_loss: 0.1025 - val_accuracy: 0.9655 - val_precision_4: 0.9697 - val_recall_4: 0.9585
# Epoch 5/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0374 - accuracy: 0.9884 - precision_4: 0.9873 - recall_4: 0.9884 - val_loss: 0.1042 - val_accuracy: 0.9644 - val_precision_4: 0.9754 - val_recall_4: 0.9501
# Epoch 6/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0299 - accuracy: 0.9904 - precision_4: 0.9899 - recall_4: 0.9899 - val_loss: 0.1126 - val_accuracy: 0.9667 - val_precision_4: 0.9493 - val_recall_4: 0.9836
# Epoch 7/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0233 - accuracy: 0.9923 - precision_4: 0.9921 - recall_4: 0.9918 - val_loss: 0.1046 - val_accuracy: 0.9692 - val_precision_4: 0.9757 - val_recall_4: 0.9602
# Epoch 8/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0192 - accuracy: 0.9939 - precision_4: 0.9932 - recall_4: 0.9940 - val_loss: 0.0948 - val_accuracy: 0.9717 - val_precision_4: 0.9811 - val_recall_4: 0.9599
# Epoch 9/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0170 - accuracy: 0.9950 - precision_4: 0.9949 - recall_4: 0.9947 - val_loss: 0.1521 - val_accuracy: 0.9607 - val_precision_4: 0.9854 - val_recall_4: 0.9325
# Epoch 10/10
# 449/449 [==============================] - 4s 9ms/step - loss: 0.0182 - accuracy: 0.9938 - precision_4: 0.9936 - recall_4: 0.9934 - val_loss: 0.1077 - val_accuracy: 0.9719 - val_precision_4: 0.9758 - val_recall_4: 0.9657
# 281/281 [==============================] - 1s 4ms/step - loss: 0.1228 - accuracy: 0.9679 - precision_4: 0.9706 - recall_4: 0.9610
# Best Model: Model_4

# %%
from matplotlib import pyplot as plt

# %%
plt.title('model training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model training accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['accuracy'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_accuracy'], label="model_{}".format(key))
plt.legend()

# %%
print("Loss: {}, Accuracy: {}, Precision: {}, Recall: {}, F1 Score: {}".format(
    np.average(loss), np.average(accuracy), np.average(precision), np.average(recall), np.average(F1)
))
# Out:
# Loss: 0.14436950385570527, Accuracy: 0.9642538785934448, Precision: 0.9597727298736572, Recall: 0.9647197961807251, F1 Score: 0.9621600380270028

# %%
best_model.save("Hybrid_ISOT")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Hybrid_ISOT\assets
# INFO:tensorflow:Assets written to: Hybrid_ISOT\assets

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = [{'Loss': round(np.average(loss), 3), 'Accuracy': round(np.average(accuracy), 3), 'Precision': round(np.average(precision), 3),
         'Recall': round(np.average(recall), 3), 'F1 Score': round(np.average(F1), 3)},
        ]
df = pd.DataFrame(data)

# %%
dir = os.getcwd()
print(dir)

# %%
change_dir = os.path.dirname(dir)
subdir = "results"
dir_path = os.path.join(change_dir, subdir)
print(dir_path)

# %%
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
    print(f"Created directory {dir_path}")
else:
    print(f"Directory {dir_path} already exists")

# %%
# Create a figure and plot the DataFrame as a table
fig, ax = plt.subplots()
ax.axis('off')
ax.axis('tight')
table = ax.table(cellText=df.values, colLabels=df.columns, loc='center')
table.auto_set_font_size(False)
table.set_fontsize(12)

# Save the figure as a PNG image
plt.savefig('../results/model_hybrid_isot_cross_result.png')

# %% [markdown]
# ### Generalization

# %%
fakes_column_names = ["lemmatized_clean_final_article", "labels"]
fakes_data = pd.read_csv("../Preprocessed_Dataset/Fakes_Preprocessed_Data.csv", encoding='utf-8', encoding_errors='ignore')[fakes_column_names]
fnc_column_names = ["lemmatized_clean_final_article", "labels"]
fnc_data = pd.read_csv("../Preprocessed_Dataset/fnc1_Preprocessed_Data.csv", encoding='utf-8', encoding_errors='ignore')[fnc_column_names]

# %%
fakes_x = token.texts_to_sequences(fakes_data[fakes_column_names[0]])
fakes_x = keras.preprocessing.sequence.pad_sequences(fakes_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
fakes_y = fakes_data[fakes_column_names[1]]

fakes_loss, fakes_accuracy, fakes_precision, fakes_recall = best_model.evaluate(x=fakes_x, y=fakes_y)
fakes_F1 = 2 * (fakes_precision * fakes_recall) / (fakes_precision + fakes_recall)
print("FAKES Loss: {}, FAKES Accuracy: {}, FAKES Precision: {}, FAKES Recall: {}, FAKES F1: {}".format(fakes_loss, fakes_accuracy, fakes_precision, fakes_recall, fakes_F1))
# Out:
# 26/26 [==============================] - 0s 12ms/step - loss: 4.1085 - accuracy: 0.4714 - precision_4: 0.5714 - recall_4: 0.0094
# FAKES Loss: 4.108481407165527, FAKES Accuracy: 0.47139304876327515, FAKES Precision: 0.5714285969734192, FAKES Recall: 0.009389671497046947, FAKES F1: 0.01847575085311447

# %%
fnc_x = token.texts_to_sequences(fnc_data[fnc_column_names[0]])
fnc_x = keras.preprocessing.sequence.pad_sequences(fnc_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
fnc_y = fnc_data[fnc_column_names[1]]

fnc_loss, fnc_accuracy, fnc_precision, fnc_recall = best_model.evaluate(x=fnc_x, y=fnc_y)
fnc_F1 = 2 * (fnc_precision * fnc_recall) / (fnc_precision + fnc_recall)
print("FNC Loss: {}, FNC Accuracy: {}, FNC Precision: {}, FNC Recall: {}, FNC F1: {}".format(fnc_loss, fnc_accuracy, fnc_precision, fnc_recall, fnc_F1))
# Out:
# 142/142 [==============================] - 1s 6ms/step - loss: 5.8087 - accuracy: 0.2231 - precision_4: 0.8590 - recall_4: 0.0546
# FNC Loss: 5.808687686920166, FNC Accuracy: 0.22310757637023926, FNC Precision: 0.8589743375778198, FNC Recall: 0.054649267345666885, FNC F1: 0.10276073858947345
