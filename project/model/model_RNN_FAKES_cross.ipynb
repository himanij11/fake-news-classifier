# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import numpy as np

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11429416154374147974
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3643801600
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4279570254622860283
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
# MAX_VNUM = 20000
SEQUENCE_LENGTH = 300
EMBED_DIMENSION = 100
BATCH_SIZE = 64
K_FOLD = 5

# %%
column_names = ["lemmatized_clean_final_article", "labels"]
data = pd.read_csv("../Preprocessed_Dataset/Fakes_Preprocessed_Data.csv", encoding='utf-8', encoding_errors='ignore')[column_names]
train, test = train_test_split(data, test_size=0.2)

# %%
token = keras.preprocessing.text.Tokenizer()
token.fit_on_texts(data[column_names[0]])
vocab_size = len(token.word_index) + 2

# %%
embedding_vector = {}
f = open('../data/glove.6B.100d.txt')
for line in tqdm(f):
    word, coefs = line.split(maxsplit=1)
    coefs = np.fromstring(coefs, "f", sep=" ")
    embedding_vector[word] = coefs
embedding_matrix = np.zeros((vocab_size, EMBED_DIMENSION))
for word,i in tqdm(token.word_index.items()):
    embedding_value = embedding_vector.get(word)
    if embedding_value is not None:
        embedding_matrix[i] = embedding_value
# Out:
# 400000it [00:08, 44700.72it/s]
# 100%|██████████| 10014/10014 [00:00<00:00, 1763076.03it/s]

# %% [markdown]
# ### Model

# %%
def model_generator():
    model = keras.models.Sequential()
    model.add(layers.Embedding(input_dim=vocab_size, output_dim=EMBED_DIMENSION, 
                        embeddings_initializer=keras.initializers.Constant(embedding_matrix), 
                        input_length=SEQUENCE_LENGTH, trainable = False))
    # model.add(layers.Permute((2, 1)))
    # model.add(layers.Conv1D(128, 5, activation='relu', name="Conv1D"))
    # model.add(layers.MaxPooling1D(pool_size=2, name="MaxPooling1D"))
    model.add(layers.LSTM(32, 
                        #   activation=None, 
                          name="LSTM"))
    model.add(layers.Dense(1, activation="sigmoid"))
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=[
        "accuracy",
        tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
    ])
    return model

# %%
train_x = token.texts_to_sequences(train[column_names[0]])
train_x = keras.preprocessing.sequence.pad_sequences(train_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
train_y = train[column_names[1]]

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = K_FOLD)
history = {}
loss, accuracy, precision, recall, F1 = np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD)
id = 0
epochs = 10
test_x = token.texts_to_sequences(test[column_names[0]])
test_x = keras.preprocessing.sequence.pad_sequences(test_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
test_y = test[column_names[1]]
best_model = None
best_f1 = 0
best_id = 0
for train_index, val_index in kf.split(train_x, train_y):
    training_x, training_y = train_x[train_index], train_y.iloc[train_index]
    validation_x, validation_y = train_x[val_index], train_y.iloc[val_index]
    model = model_generator()
    history[id] = model.fit(x=training_x, y=training_y, validation_data=(validation_x, validation_y),
                                               epochs=epochs, batch_size=BATCH_SIZE)
    loss[id], accuracy[id], precision[id], recall[id] = model.evaluate(x=test_x, y=test_y)
    F1[id] = 2 * (precision[id] * recall[id]) / (precision[id] + recall[id])
    if F1[id] > best_f1:
        best_model = model
        best_f1 = F1[id]
        best_id = id
    id += 1
print("Best Model: Model_{}".format(best_id))
# Out:
# Epoch 1/10
# 9/9 [==============================] - 4s 91ms/step - loss: 0.6929 - accuracy: 0.5272 - precision: 0.5371 - recall: 0.8881 - val_loss: 0.6901 - val_accuracy: 0.5349 - val_precision: 0.5349 - val_recall: 1.0000
# Epoch 2/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6912 - accuracy: 0.5370 - precision: 0.5382 - recall: 0.9928 - val_loss: 0.6910 - val_accuracy: 0.5426 - val_precision: 0.5391 - val_recall: 1.0000
# Epoch 3/10
# 9/9 [==============================] - 0s 31ms/step - loss: 0.6909 - accuracy: 0.5409 - precision: 0.5403 - recall: 0.9928 - val_loss: 0.6912 - val_accuracy: 0.5426 - val_precision: 0.5391 - val_recall: 1.0000
# Epoch 4/10
# 9/9 [==============================] - 0s 32ms/step - loss: 0.6926 - accuracy: 0.5331 - precision: 0.5393 - recall: 0.9170 - val_loss: 0.6926 - val_accuracy: 0.5271 - val_precision: 0.5345 - val_recall: 0.8986
# Epoch 5/10
# 9/9 [==============================] - 0s 30ms/step - loss: 0.6918 - accuracy: 0.5428 - precision: 0.5465 - recall: 0.8917 - val_loss: 0.6917 - val_accuracy: 0.5271 - val_precision: 0.5333 - val_recall: 0.9275
# Epoch 6/10
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6906 - accuracy: 0.5409 - precision: 0.5419 - recall: 0.9567 - val_loss: 0.6906 - val_accuracy: 0.5581 - val_precision: 0.5476 - val_recall: 1.0000
# Epoch 7/10
# 9/9 [==============================] - 0s 30ms/step - loss: 0.6892 - accuracy: 0.5409 - precision: 0.5411 - recall: 0.9747 - val_loss: 0.6904 - val_accuracy: 0.5581 - val_precision: 0.5476 - val_recall: 1.0000
# Epoch 8/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6891 - accuracy: 0.5447 - precision: 0.5427 - recall: 0.9856 - val_loss: 0.6903 - val_accuracy: 0.5349 - val_precision: 0.5349 - val_recall: 1.0000
# Epoch 9/10
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6903 - accuracy: 0.5409 - precision: 0.5400 - recall: 1.0000 - val_loss: 0.6906 - val_accuracy: 0.5349 - val_precision: 0.5349 - val_recall: 1.0000
# Epoch 10/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6909 - accuracy: 0.5389 - precision: 0.5389 - recall: 1.0000 - val_loss: 0.6905 - val_accuracy: 0.5349 - val_precision: 0.5349 - val_recall: 1.0000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6939 - accuracy: 0.4969 - precision: 0.4969 - recall: 1.0000
# Epoch 1/10
# 9/9 [==============================] - 2s 96ms/step - loss: 0.6964 - accuracy: 0.4475 - precision_1: 0.4694 - recall_1: 0.0819 - val_loss: 0.6918 - val_accuracy: 0.4884 - val_precision_1: 0.4762 - val_recall_1: 0.1538
# Epoch 2/10
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6934 - accuracy: 0.4903 - precision_1: 0.6118 - recall_1: 0.1851 - val_loss: 0.6936 - val_accuracy: 0.4806 - val_precision_1: 0.4688 - val_recall_1: 0.2308
# Epoch 3/10
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6937 - accuracy: 0.5136 - precision_1: 0.5548 - recall_1: 0.5587 - val_loss: 0.6967 - val_accuracy: 0.5039 - val_precision_1: 0.5039 - val_recall_1: 1.0000
# Epoch 4/10
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6928 - accuracy: 0.5467 - precision_1: 0.5467 - recall_1: 1.0000 - val_loss: 0.6983 - val_accuracy: 0.5039 - val_precision_1: 0.5039 - val_recall_1: 1.0000
# Epoch 5/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6919 - accuracy: 0.5467 - precision_1: 0.5467 - recall_1: 1.0000 - val_loss: 0.6979 - val_accuracy: 0.5039 - val_precision_1: 0.5039 - val_recall_1: 1.0000
# Epoch 6/10
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6905 - accuracy: 0.5467 - precision_1: 0.5467 - recall_1: 1.0000 - val_loss: 0.6968 - val_accuracy: 0.5039 - val_precision_1: 0.5039 - val_recall_1: 1.0000
# Epoch 7/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6892 - accuracy: 0.5467 - precision_1: 0.5467 - recall_1: 1.0000 - val_loss: 0.6993 - val_accuracy: 0.5039 - val_precision_1: 0.5039 - val_recall_1: 1.0000
# Epoch 8/10
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6882 - accuracy: 0.5467 - precision_1: 0.5467 - recall_1: 1.0000 - val_loss: 0.7014 - val_accuracy: 0.5039 - val_precision_1: 0.5039 - val_recall_1: 1.0000
# Epoch 9/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6874 - accuracy: 0.5467 - precision_1: 0.5467 - recall_1: 1.0000 - val_loss: 0.7012 - val_accuracy: 0.5039 - val_precision_1: 0.5039 - val_recall_1: 1.0000
# Epoch 10/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6871 - accuracy: 0.5467 - precision_1: 0.5467 - recall_1: 1.0000 - val_loss: 0.7000 - val_accuracy: 0.5039 - val_precision_1: 0.5039 - val_recall_1: 1.0000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6937 - accuracy: 0.4969 - precision_1: 0.4969 - recall_1: 1.0000
# Epoch 1/10
# 9/9 [==============================] - 3s 95ms/step - loss: 0.6938 - accuracy: 0.4961 - precision_2: 0.5158 - recall_2: 0.8388 - val_loss: 0.6912 - val_accuracy: 0.5659 - val_precision_2: 0.5659 - val_recall_2: 1.0000
# Epoch 2/10
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6916 - accuracy: 0.5311 - precision_2: 0.5311 - recall_2: 1.0000 - val_loss: 0.6918 - val_accuracy: 0.5659 - val_precision_2: 0.5659 - val_recall_2: 1.0000
# Epoch 3/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6914 - accuracy: 0.5272 - precision_2: 0.5300 - recall_2: 0.9707 - val_loss: 0.6928 - val_accuracy: 0.5349 - val_precision_2: 0.5537 - val_recall_2: 0.9178
# Epoch 4/10
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6908 - accuracy: 0.5272 - precision_2: 0.5300 - recall_2: 0.9707 - val_loss: 0.6901 - val_accuracy: 0.5659 - val_precision_2: 0.5659 - val_recall_2: 1.0000
# Epoch 5/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6904 - accuracy: 0.5311 - precision_2: 0.5311 - recall_2: 1.0000 - val_loss: 0.6892 - val_accuracy: 0.5659 - val_precision_2: 0.5659 - val_recall_2: 1.0000
# Epoch 6/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6916 - accuracy: 0.5311 - precision_2: 0.5311 - recall_2: 1.0000 - val_loss: 0.6892 - val_accuracy: 0.5659 - val_precision_2: 0.5659 - val_recall_2: 1.0000
# Epoch 7/10
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6948 - accuracy: 0.5311 - precision_2: 0.5311 - recall_2: 1.0000 - val_loss: 0.6905 - val_accuracy: 0.5659 - val_precision_2: 0.5659 - val_recall_2: 1.0000
# Epoch 8/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6956 - accuracy: 0.5311 - precision_2: 0.5311 - recall_2: 1.0000 - val_loss: 0.6896 - val_accuracy: 0.5659 - val_precision_2: 0.5659 - val_recall_2: 1.0000
# Epoch 9/10
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6938 - accuracy: 0.5311 - precision_2: 0.5311 - recall_2: 1.0000 - val_loss: 0.6886 - val_accuracy: 0.5659 - val_precision_2: 0.5659 - val_recall_2: 1.0000
# Epoch 10/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6900 - accuracy: 0.5311 - precision_2: 0.5311 - recall_2: 1.0000 - val_loss: 0.6907 - val_accuracy: 0.5271 - val_precision_2: 0.5484 - val_recall_2: 0.9315
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6942 - accuracy: 0.4907 - precision_2: 0.4937 - recall_2: 0.9750
# Epoch 1/10
# 9/9 [==============================] - 3s 92ms/step - loss: 0.6924 - accuracy: 0.5320 - precision_3: 0.5340 - recall_3: 0.9194 - val_loss: 0.6918 - val_accuracy: 0.5703 - val_precision_3: 0.5703 - val_recall_3: 1.0000
# Epoch 2/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6914 - accuracy: 0.5301 - precision_3: 0.5301 - recall_3: 1.0000 - val_loss: 0.6937 - val_accuracy: 0.5703 - val_precision_3: 0.5703 - val_recall_3: 1.0000
# Epoch 3/10
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6913 - accuracy: 0.5282 - precision_3: 0.5292 - recall_3: 0.9963 - val_loss: 0.6948 - val_accuracy: 0.5703 - val_precision_3: 0.5703 - val_recall_3: 1.0000
# Epoch 4/10
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6907 - accuracy: 0.5282 - precision_3: 0.5292 - recall_3: 0.9963 - val_loss: 0.6958 - val_accuracy: 0.5703 - val_precision_3: 0.5703 - val_recall_3: 1.0000
# Epoch 5/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6904 - accuracy: 0.5301 - precision_3: 0.5301 - recall_3: 1.0000 - val_loss: 0.6958 - val_accuracy: 0.5703 - val_precision_3: 0.5703 - val_recall_3: 1.0000
# Epoch 6/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6906 - accuracy: 0.5282 - precision_3: 0.5292 - recall_3: 0.9963 - val_loss: 0.6946 - val_accuracy: 0.5703 - val_precision_3: 0.5703 - val_recall_3: 1.0000
# Epoch 7/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6902 - accuracy: 0.5282 - precision_3: 0.5292 - recall_3: 0.9963 - val_loss: 0.6936 - val_accuracy: 0.5703 - val_precision_3: 0.5703 - val_recall_3: 1.0000
# Epoch 8/10
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6901 - accuracy: 0.5301 - precision_3: 0.5302 - recall_3: 0.9963 - val_loss: 0.6906 - val_accuracy: 0.5781 - val_precision_3: 0.5748 - val_recall_3: 1.0000
# Epoch 9/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6912 - accuracy: 0.5340 - precision_3: 0.5332 - recall_3: 0.9707 - val_loss: 0.6898 - val_accuracy: 0.5781 - val_precision_3: 0.5748 - val_recall_3: 1.0000
# Epoch 10/10
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6903 - accuracy: 0.5379 - precision_3: 0.5344 - recall_3: 0.9963 - val_loss: 0.6890 - val_accuracy: 0.5703 - val_precision_3: 0.5703 - val_recall_3: 1.0000
# 6/6 [==============================] - 1s 10ms/step - loss: 0.6944 - accuracy: 0.4969 - precision_3: 0.4969 - recall_3: 1.0000
# Epoch 1/10
# 9/9 [==============================] - 3s 89ms/step - loss: 0.6976 - accuracy: 0.4874 - precision_4: 0.5280 - recall_4: 0.5393 - val_loss: 0.6949 - val_accuracy: 0.4453 - val_precision_4: 0.4762 - val_recall_4: 0.7576
# Epoch 2/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6906 - accuracy: 0.5398 - precision_4: 0.5441 - recall_4: 0.9464 - val_loss: 0.6953 - val_accuracy: 0.5156 - val_precision_4: 0.5156 - val_recall_4: 1.0000
# Epoch 3/10
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6914 - accuracy: 0.5437 - precision_4: 0.5437 - recall_4: 1.0000 - val_loss: 0.6972 - val_accuracy: 0.5156 - val_precision_4: 0.5156 - val_recall_4: 1.0000
# Epoch 4/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6909 - accuracy: 0.5437 - precision_4: 0.5437 - recall_4: 1.0000 - val_loss: 0.6977 - val_accuracy: 0.5156 - val_precision_4: 0.5156 - val_recall_4: 1.0000
# Epoch 5/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6894 - accuracy: 0.5437 - precision_4: 0.5437 - recall_4: 1.0000 - val_loss: 0.6978 - val_accuracy: 0.5156 - val_precision_4: 0.5156 - val_recall_4: 1.0000
# Epoch 6/10
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6879 - accuracy: 0.5437 - precision_4: 0.5437 - recall_4: 1.0000 - val_loss: 0.6982 - val_accuracy: 0.5078 - val_precision_4: 0.5118 - val_recall_4: 0.9848
# Epoch 7/10
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6880 - accuracy: 0.5553 - precision_4: 0.5526 - recall_4: 0.9571 - val_loss: 0.7001 - val_accuracy: 0.4688 - val_precision_4: 0.4911 - val_recall_4: 0.8333
# Epoch 8/10
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6881 - accuracy: 0.5456 - precision_4: 0.5504 - recall_4: 0.8964 - val_loss: 0.7015 - val_accuracy: 0.4688 - val_precision_4: 0.4911 - val_recall_4: 0.8333
# Epoch 9/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6876 - accuracy: 0.5553 - precision_4: 0.5539 - recall_4: 0.9357 - val_loss: 0.7021 - val_accuracy: 0.4922 - val_precision_4: 0.5040 - val_recall_4: 0.9545
# Epoch 10/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6868 - accuracy: 0.5553 - precision_4: 0.5507 - recall_4: 0.9893 - val_loss: 0.7028 - val_accuracy: 0.5000 - val_precision_4: 0.5079 - val_recall_4: 0.9697
# 6/6 [==============================] - 1s 9ms/step - loss: 0.6995 - accuracy: 0.4907 - precision_4: 0.4937 - recall_4: 0.9750
# Best Model: Model_0

# %%
from matplotlib import pyplot as plt

# %%
plt.title('model training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model training accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['accuracy'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_accuracy'], label="model_{}".format(key))
plt.legend()

# %%
print("Loss: {}, Accuracy: {}, Precision: {}, Recall: {}, F1 Score: {}".format(
    np.average(loss), np.average(accuracy), np.average(precision), np.average(recall), np.average(F1)
))
# Out:
# Loss: 0.695113456249237, Accuracy: 0.49440994262695315, Precision: 0.49560500383377076, Recall: 0.9900000095367432, F1 Score: 0.6605251281618925

# %%
best_model.save("RNN_FAKES")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: RNN_FAKES\assets
# INFO:tensorflow:Assets written to: RNN_FAKES\assets
