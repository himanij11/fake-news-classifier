# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import numpy as np

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10729990436076685019
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3643801600
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2859221941665269624
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
# MAX_VNUM = 20000
SEQUENCE_LENGTH = 300
EMBED_DIMENSION = 100
BATCH_SIZE = 64
K_FOLD = 5
NUM_HEADS = 4
FF_DIMENSION = 32

# %%
column_names = ["lemmatized_clean_final_article", "labels"]
data = pd.read_csv("../Preprocessed_Dataset/fnc-1_Preprocessed_Data.csv", encoding='utf-8', encoding_errors='ignore')[column_names]
train, test = train_test_split(data, test_size=0.2)

# %%
token = keras.preprocessing.text.Tokenizer()
token.fit_on_texts(data[column_names[0]])
vocab_size = len(token.word_index) + 2

# %%
embedding_vector = {}
f = open('../data/glove.6B.100d.txt')
for line in tqdm(f):
    word, coefs = line.split(maxsplit=1)
    coefs = np.fromstring(coefs, "f", sep=" ")
    embedding_vector[word] = coefs
embedding_matrix = np.zeros((vocab_size, EMBED_DIMENSION))
for word,i in tqdm(token.word_index.items()):
    embedding_value = embedding_vector.get(word)
    if embedding_value is not None:
        embedding_matrix[i] = embedding_value
# Out:
# 400000it [00:09, 44378.29it/s]
# 100%|██████████| 17539/17539 [00:00<00:00, 1678238.30it/s]

# %% [markdown]
# ### Model

# %%
class MultiHeadSelfAttention(layers.Layer):
    def __init__(self, embed_dim, num_heads=8):
        super(MultiHeadSelfAttention, self).__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        if embed_dim % num_heads !=0:
             raise ValueError(
                f"embedding dimension = {embed_dim} should be divisible by number of heads = {num_heads}"
            )
        self.projection_dim = embed_dim // num_heads
        self.query_dense = layers.Dense(embed_dim)
        self.key_dense = layers.Dense(embed_dim)
        self.value_dense = layers.Dense(embed_dim)
        self.combine_heads = layers.Dense(embed_dim)
    
    def attention(self, query, key, value):
        score = tf.matmul(query, key, transpose_b = True)
        dim_key = tf.cast(tf.shape(key)[-1], tf.float32)
        scaled_score = score / tf.math.sqrt(dim_key)
        weights = tf.nn.softmax(scaled_score, axis=-1)
        output = tf.matmul(weights, value)
        return output, weights
    
    def seperate_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim))
        return tf.transpose(x, perm = [0, 2, 1, 3])
    
    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        query = self.query_dense(inputs)
        key = self.key_dense(inputs)
        value = self.value_dense(inputs)
        
        query = self.seperate_heads(query, batch_size)
        key = self.seperate_heads(key, batch_size)
        value = self.seperate_heads(value, batch_size)
        
        attention, weights = self.attention(query, key, value)
        
        attention = tf.transpose(attention, perm=[0,2,1,3])
        
        concat_attention = tf.reshape(attention, (batch_size, -1, self.embed_dim))
        
        output = self.combine_heads(concat_attention)
        
        return output

# %%
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.embedding = layers.Embedding(
            input_dim=embedding_matrix.shape[0],
            output_dim=embedding_matrix.shape[1],
            weights=[embedding_matrix],
            input_length=SEQUENCE_LENGTH,
            trainable=False  # Set to False to keep the pre-trained embeddings fixed
        )
        self.att = MultiHeadSelfAttention(embed_dim, num_heads)
        self.ffn = keras.Sequential(
            [layers.Dense(ff_dim, activation='relu'), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)
    
    def call(self, inputs, training):
        attn_output = self.att(inputs)
        attn_output = self.dropout1(attn_output, training = training)
        
        out1 = self.layernorm1(inputs + attn_output)
        
        ffn_output = self.ffn(out1)
        
        fnn_output = self.dropout2(ffn_output, training = training)
        return self.layernorm2(out1 + ffn_output)

# %%
class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = layers.Embedding(input_dim = vocab_size, output_dim = embed_dim)
        self.pos_emb = layers.Embedding(input_dim = maxlen, output_dim = embed_dim)
    
    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit = maxlen, delta=1)
        positions = self.pos_emb(positions)
        
        x = self.token_emb(x)
        
        return x + positions

# %%
def model_generator():
    inputs = layers.Input(shape = (SEQUENCE_LENGTH,))
    embedding_layer = TokenAndPositionEmbedding(SEQUENCE_LENGTH, vocab_size, EMBED_DIMENSION)
    x = embedding_layer(inputs)
    transformer_block = TransformerBlock(EMBED_DIMENSION, NUM_HEADS, FF_DIMENSION)

    x = transformer_block(x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.1)(x)
    x = layers.Dense(10, activation='relu')(x)
    x = layers.Dropout(0.1)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = keras.Model(inputs = inputs, outputs = outputs)
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy',tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])
    return model

# %%
train_x = token.texts_to_sequences(train[column_names[0]])
train_x = keras.preprocessing.sequence.pad_sequences(train_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
train_y = train[column_names[1]]

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = K_FOLD)
history = {}
loss, accuracy, precision, recall, F1 = np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD)
id = 0
epochs = 10
test_x = token.texts_to_sequences(test[column_names[0]])
test_x = keras.preprocessing.sequence.pad_sequences(test_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
test_y = test[column_names[1]]
best_model = None
best_f1 = 0
best_id = 0
for train_index, val_index in kf.split(train_x, train_y):
    training_x, training_y = train_x[train_index], train_y.iloc[train_index]
    validation_x, validation_y = train_x[val_index], train_y.iloc[val_index]
    model = model_generator()
    history[id] = model.fit(x=training_x, y=training_y, validation_data=(validation_x, validation_y),
                                               epochs=epochs, batch_size=BATCH_SIZE)
    loss[id], accuracy[id], precision[id], recall[id] = model.evaluate(x=test_x, y=test_y)
    F1[id] = 2 * (precision[id] * recall[id]) / (precision[id] + recall[id])
    if F1[id] > best_f1:
        best_model = model
        best_f1 = F1[id]
        best_id = id
    id += 1
print("Best Model: Model_{}".format(best_id))
# Out:
# Epoch 1/10
# 46/46 [==============================] - 4s 37ms/step - loss: 0.4502 - accuracy: 0.8170 - precision: 0.8187 - recall: 0.9975 - val_loss: 0.4056 - val_accuracy: 0.7898 - val_precision: 0.7898 - val_recall: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.3286 - accuracy: 0.8291 - precision: 0.8455 - recall: 0.9683 - val_loss: 0.4525 - val_accuracy: 0.8077 - val_precision: 0.8077 - val_recall: 0.9930
# Epoch 3/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2957 - accuracy: 0.8509 - precision: 0.8935 - recall: 0.9286 - val_loss: 0.4226 - val_accuracy: 0.8022 - val_precision: 0.8579 - val_recall: 0.8984
# Epoch 4/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2640 - accuracy: 0.8689 - precision: 0.9223 - recall: 0.9172 - val_loss: 0.4014 - val_accuracy: 0.8077 - val_precision: 0.8789 - val_recall: 0.8774
# Epoch 5/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2706 - accuracy: 0.8582 - precision: 0.9184 - recall: 0.9075 - val_loss: 0.3990 - val_accuracy: 0.7967 - val_precision: 0.8786 - val_recall: 0.8616
# Epoch 6/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2435 - accuracy: 0.8706 - precision: 0.9373 - recall: 0.9024 - val_loss: 0.4227 - val_accuracy: 0.8064 - val_precision: 0.8869 - val_recall: 0.8651
# Epoch 7/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2205 - accuracy: 0.8893 - precision: 0.9410 - recall: 0.9227 - val_loss: 0.6305 - val_accuracy: 0.8160 - val_precision: 0.8578 - val_recall: 0.9194
# Epoch 8/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.1925 - accuracy: 0.9070 - precision: 0.9725 - recall: 0.9122 - val_loss: 0.5560 - val_accuracy: 0.8188 - val_precision: 0.8793 - val_recall: 0.8932
# Epoch 9/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.1592 - accuracy: 0.9274 - precision: 0.9821 - recall: 0.9282 - val_loss: 0.6122 - val_accuracy: 0.8230 - val_precision: 0.8852 - val_recall: 0.8914
# Epoch 10/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.1311 - accuracy: 0.9346 - precision: 0.9901 - recall: 0.9295 - val_loss: 0.6132 - val_accuracy: 0.8437 - val_precision: 0.8948 - val_recall: 0.9089
# 29/29 [==============================] - 0s 7ms/step - loss: 0.4219 - accuracy: 0.8706 - precision: 0.9260 - recall: 0.9147
# Epoch 1/10
# 46/46 [==============================] - 3s 36ms/step - loss: 0.4565 - accuracy: 0.8028 - precision_1: 0.8089 - recall_1: 0.9902 - val_loss: 0.3324 - val_accuracy: 0.8313 - val_precision_1: 0.8313 - val_recall_1: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.3353 - accuracy: 0.8219 - precision_1: 0.8532 - recall_1: 0.9418 - val_loss: 0.3323 - val_accuracy: 0.8617 - val_precision_1: 0.8848 - val_recall_1: 0.9584
# Epoch 3/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.3129 - accuracy: 0.8423 - precision_1: 0.8828 - recall_1: 0.9281 - val_loss: 0.3333 - val_accuracy: 0.8492 - val_precision_1: 0.9114 - val_recall_1: 0.9068
# Epoch 4/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2888 - accuracy: 0.8447 - precision_1: 0.9045 - recall_1: 0.9033 - val_loss: 0.3503 - val_accuracy: 0.8548 - val_precision_1: 0.8937 - val_recall_1: 0.9368
# Epoch 5/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2856 - accuracy: 0.8502 - precision_1: 0.9097 - recall_1: 0.9046 - val_loss: 0.3653 - val_accuracy: 0.8437 - val_precision_1: 0.8496 - val_recall_1: 0.9867
# Epoch 6/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2631 - accuracy: 0.8630 - precision_1: 0.9189 - recall_1: 0.9110 - val_loss: 0.3648 - val_accuracy: 0.8645 - val_precision_1: 0.8973 - val_recall_1: 0.9451
# Epoch 7/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2462 - accuracy: 0.8737 - precision_1: 0.9402 - recall_1: 0.9012 - val_loss: 0.3697 - val_accuracy: 0.8824 - val_precision_1: 0.9095 - val_recall_1: 0.9534
# Epoch 8/10
# 46/46 [==============================] - 1s 27ms/step - loss: 0.2208 - accuracy: 0.8938 - precision_1: 0.9515 - recall_1: 0.9153 - val_loss: 0.3306 - val_accuracy: 0.8921 - val_precision_1: 0.9425 - val_recall_1: 0.9268
# Epoch 9/10
# 46/46 [==============================] - 1s 29ms/step - loss: 0.1779 - accuracy: 0.9163 - precision_1: 0.9777 - recall_1: 0.9175 - val_loss: 0.3842 - val_accuracy: 0.8811 - val_precision_1: 0.9342 - val_recall_1: 0.9218
# Epoch 10/10
# 46/46 [==============================] - 1s 27ms/step - loss: 0.1621 - accuracy: 0.9315 - precision_1: 0.9881 - recall_1: 0.9264 - val_loss: 0.3169 - val_accuracy: 0.8838 - val_precision_1: 0.9591 - val_recall_1: 0.8985
# 29/29 [==============================] - 0s 8ms/step - loss: 0.3230 - accuracy: 0.8750 - precision_1: 0.9603 - recall_1: 0.8836
# Epoch 1/10
# 46/46 [==============================] - 4s 43ms/step - loss: 0.4765 - accuracy: 0.8115 - precision_2: 0.8196 - recall_2: 0.9865 - val_loss: 0.3933 - val_accuracy: 0.8119 - val_precision_2: 0.8119 - val_recall_2: 0.9948
# Epoch 2/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.3443 - accuracy: 0.8336 - precision_2: 0.8534 - recall_2: 0.9615 - val_loss: 0.3872 - val_accuracy: 0.8160 - val_precision_2: 0.8801 - val_recall_2: 0.8908
# Epoch 3/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.3462 - accuracy: 0.8416 - precision_2: 0.8745 - recall_2: 0.9412 - val_loss: 0.3583 - val_accuracy: 0.8188 - val_precision_2: 0.8620 - val_recall_2: 0.9203
# Epoch 4/10
# 46/46 [==============================] - 1s 26ms/step - loss: 0.2841 - accuracy: 0.8658 - precision_2: 0.9089 - recall_2: 0.9289 - val_loss: 0.3556 - val_accuracy: 0.8368 - val_precision_2: 0.8649 - val_recall_2: 0.9428
# Epoch 5/10
# 46/46 [==============================] - 1s 26ms/step - loss: 0.2651 - accuracy: 0.8682 - precision_2: 0.9088 - recall_2: 0.9323 - val_loss: 0.4608 - val_accuracy: 0.8147 - val_precision_2: 0.8272 - val_recall_2: 0.9705
# Epoch 6/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2504 - accuracy: 0.8699 - precision_2: 0.9183 - recall_2: 0.9229 - val_loss: 0.4849 - val_accuracy: 0.8147 - val_precision_2: 0.8382 - val_recall_2: 0.9515
# Epoch 7/10
# 46/46 [==============================] - 1s 26ms/step - loss: 0.2297 - accuracy: 0.8824 - precision_2: 0.9284 - recall_2: 0.9276 - val_loss: 0.4752 - val_accuracy: 0.8188 - val_precision_2: 0.8680 - val_recall_2: 0.9116
# Epoch 8/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.1982 - accuracy: 0.9021 - precision_2: 0.9479 - recall_2: 0.9314 - val_loss: 0.4458 - val_accuracy: 0.8492 - val_precision_2: 0.9077 - val_recall_2: 0.9029
# Epoch 9/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.1623 - accuracy: 0.9194 - precision_2: 0.9700 - recall_2: 0.9301 - val_loss: 0.4168 - val_accuracy: 0.8631 - val_precision_2: 0.9361 - val_recall_2: 0.8891
# Epoch 10/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.1378 - accuracy: 0.9374 - precision_2: 0.9857 - recall_2: 0.9369 - val_loss: 0.4924 - val_accuracy: 0.8700 - val_precision_2: 0.9215 - val_recall_2: 0.9151
# 29/29 [==============================] - 0s 7ms/step - loss: 0.4302 - accuracy: 0.8695 - precision_2: 0.9283 - recall_2: 0.9107
# Epoch 1/10
# 46/46 [==============================] - 3s 36ms/step - loss: 0.4717 - accuracy: 0.7945 - precision_3: 0.8156 - recall_3: 0.9646 - val_loss: 0.3834 - val_accuracy: 0.8230 - val_precision_3: 0.8762 - val_recall_3: 0.9144
# Epoch 2/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.3599 - accuracy: 0.8274 - precision_3: 0.8782 - recall_3: 0.9138 - val_loss: 0.3703 - val_accuracy: 0.8257 - val_precision_3: 0.8695 - val_recall_3: 0.9279
# Epoch 3/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.3119 - accuracy: 0.8409 - precision_3: 0.8905 - recall_3: 0.9163 - val_loss: 0.3501 - val_accuracy: 0.8119 - val_precision_3: 0.8938 - val_recall_3: 0.8758
# Epoch 4/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.3010 - accuracy: 0.8437 - precision_3: 0.9053 - recall_3: 0.9014 - val_loss: 0.3625 - val_accuracy: 0.8243 - val_precision_3: 0.8981 - val_recall_3: 0.8876
# Epoch 5/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2768 - accuracy: 0.8571 - precision_3: 0.9089 - recall_3: 0.9155 - val_loss: 0.3432 - val_accuracy: 0.8147 - val_precision_3: 0.8825 - val_recall_3: 0.8943
# Epoch 6/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2612 - accuracy: 0.8724 - precision_3: 0.9258 - recall_3: 0.9159 - val_loss: 0.3925 - val_accuracy: 0.8216 - val_precision_3: 0.9104 - val_recall_3: 0.8691
# Epoch 7/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2491 - accuracy: 0.8793 - precision_3: 0.9459 - recall_3: 0.9027 - val_loss: 0.3543 - val_accuracy: 0.8326 - val_precision_3: 0.9218 - val_recall_3: 0.8708
# Epoch 8/10
# 46/46 [==============================] - 1s 26ms/step - loss: 0.2249 - accuracy: 0.8969 - precision_3: 0.9583 - recall_3: 0.9125 - val_loss: 0.3977 - val_accuracy: 0.8257 - val_precision_3: 0.9242 - val_recall_3: 0.8591
# Epoch 9/10
# 46/46 [==============================] - 1s 26ms/step - loss: 0.1831 - accuracy: 0.9201 - precision_3: 0.9813 - recall_3: 0.9189 - val_loss: 0.4715 - val_accuracy: 0.8465 - val_precision_3: 0.9145 - val_recall_3: 0.8977
# Epoch 10/10
# 46/46 [==============================] - 1s 26ms/step - loss: 0.1549 - accuracy: 0.9353 - precision_3: 0.9838 - recall_3: 0.9356 - val_loss: 0.3953 - val_accuracy: 0.8686 - val_precision_3: 0.9341 - val_recall_3: 0.9044
# 29/29 [==============================] - 0s 7ms/step - loss: 0.3578 - accuracy: 0.8717 - precision_3: 0.9320 - recall_3: 0.9093
# Epoch 1/10
# 46/46 [==============================] - 4s 37ms/step - loss: 0.4426 - accuracy: 0.8088 - precision_4: 0.8128 - recall_4: 0.9928 - val_loss: 0.3588 - val_accuracy: 0.8144 - val_precision_4: 0.8662 - val_recall_4: 0.9158
# Epoch 2/10
# 46/46 [==============================] - 1s 26ms/step - loss: 0.3323 - accuracy: 0.8441 - precision_4: 0.8740 - recall_4: 0.9437 - val_loss: 0.3521 - val_accuracy: 0.7978 - val_precision_4: 0.8746 - val_recall_4: 0.8805
# Epoch 3/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.3050 - accuracy: 0.8441 - precision_4: 0.8966 - recall_4: 0.9130 - val_loss: 0.3558 - val_accuracy: 0.8172 - val_precision_4: 0.8632 - val_recall_4: 0.9242
# Epoch 4/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2706 - accuracy: 0.8589 - precision_4: 0.9061 - recall_4: 0.9215 - val_loss: 0.3617 - val_accuracy: 0.8033 - val_precision_4: 0.8951 - val_recall_4: 0.8620
# Epoch 5/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2674 - accuracy: 0.8645 - precision_4: 0.9262 - recall_4: 0.9049 - val_loss: 0.4321 - val_accuracy: 0.8186 - val_precision_4: 0.8657 - val_recall_4: 0.9226
# Epoch 6/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2647 - accuracy: 0.8593 - precision_4: 0.9276 - recall_4: 0.8964 - val_loss: 0.3931 - val_accuracy: 0.8006 - val_precision_4: 0.9229 - val_recall_4: 0.8266
# Epoch 7/10
# 46/46 [==============================] - 1s 25ms/step - loss: 0.2367 - accuracy: 0.8838 - precision_4: 0.9478 - recall_4: 0.9066 - val_loss: 0.4171 - val_accuracy: 0.8352 - val_precision_4: 0.9116 - val_recall_4: 0.8855
# Epoch 8/10
# 46/46 [==============================] - 1s 26ms/step - loss: 0.1973 - accuracy: 0.9094 - precision_4: 0.9610 - recall_4: 0.9258 - val_loss: 0.4320 - val_accuracy: 0.8338 - val_precision_4: 0.9405 - val_recall_4: 0.8519
# Epoch 9/10
# 46/46 [==============================] - 1s 26ms/step - loss: 0.1685 - accuracy: 0.9298 - precision_4: 0.9837 - recall_4: 0.9288 - val_loss: 0.3880 - val_accuracy: 0.8380 - val_precision_4: 0.9458 - val_recall_4: 0.8519
# Epoch 10/10
# 46/46 [==============================] - 1s 26ms/step - loss: 0.1406 - accuracy: 0.9436 - precision_4: 0.9897 - recall_4: 0.9403 - val_loss: 0.3892 - val_accuracy: 0.8712 - val_precision_4: 0.9418 - val_recall_4: 0.8990
# 29/29 [==============================] - 0s 7ms/step - loss: 0.3344 - accuracy: 0.8894 - precision_4: 0.9506 - recall_4: 0.9120
# Best Model: Model_4

# %%
from matplotlib import pyplot as plt

# %%
plt.title('model training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model training accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['accuracy'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_accuracy'], label="model_{}".format(key))
plt.legend()

# %%
print("Loss: {}, Accuracy: {}, Precision: {}, Recall: {}, F1 Score: {}".format(
    np.average(loss), np.average(accuracy), np.average(precision), np.average(recall), np.average(F1)
))
# Out:
# Loss: 0.37344577312469485, Accuracy: 0.8752212405204773, Precision: 0.939454197883606, Recall: 0.9060893058776855, F1 Score: 0.922321308959108

# %%
best_model.save("Transformer_FNC")
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.embeddings.Embedding object at 0x0000018335DD2B80>, because it is not built.
# WARNING:absl:Found untraced functions such as embedding_12_layer_call_fn, embedding_12_layer_call_and_return_conditional_losses, embedding_13_layer_call_fn, embedding_13_layer_call_and_return_conditional_losses, multi_head_self_attention_4_layer_call_fn while saving (showing 5 of 55). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Transformer_FNC\assets
# INFO:tensorflow:Assets written to: Transformer_FNC\assets
