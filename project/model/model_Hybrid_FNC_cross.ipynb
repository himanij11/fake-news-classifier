# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import numpy as np

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17661397623962143942
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3643801600
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15679609186354925357
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
# MAX_VNUM = 20000
SEQUENCE_LENGTH = 300
EMBED_DIMENSION = 100
BATCH_SIZE = 64
K_FOLD = 5

# %%
column_names = ["lemmatized_clean_final_article", "labels"]
data = pd.read_csv("../Preprocessed_Dataset/fnc-1_Preprocessed_Data.csv", encoding='utf-8', encoding_errors='ignore')[column_names]
train, test = train_test_split(data, test_size=0.2)

# %%
token = keras.preprocessing.text.Tokenizer()
token.fit_on_texts(data[column_names[0]])
vocab_size = len(token.word_index) + 2

# %%
embedding_vector = {}
f = open('../data/glove.6B.100d.txt')
for line in tqdm(f):
    word, coefs = line.split(maxsplit=1)
    coefs = np.fromstring(coefs, "f", sep=" ")
    embedding_vector[word] = coefs
embedding_matrix = np.zeros((vocab_size, EMBED_DIMENSION))
for word,i in tqdm(token.word_index.items()):
    embedding_value = embedding_vector.get(word)
    if embedding_value is not None:
        embedding_matrix[i] = embedding_value
# Out:
# 400000it [00:09, 43543.96it/s]
# 100%|██████████| 17539/17539 [00:00<00:00, 1822738.37it/s]

# %% [markdown]
# ### Model

# %%
def model_generator():
    model = keras.models.Sequential()
    model.add(layers.Embedding(input_dim=vocab_size, output_dim=EMBED_DIMENSION, 
                        embeddings_initializer=keras.initializers.Constant(embedding_matrix), 
                        input_length=SEQUENCE_LENGTH, trainable = False))
    model.add(layers.Permute((2, 1)))
    model.add(layers.Conv1D(128, 5, activation='relu', name="Conv1D"))
    model.add(layers.MaxPooling1D(pool_size=2, name="MaxPooling1D"))
    model.add(layers.LSTM(32, 
                        #   activation=None, 
                          name="LSTM"))
    model.add(layers.Dense(1, activation="sigmoid"))
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=[
        "accuracy",
        tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
    ])
    return model

# %%
train_x = token.texts_to_sequences(train[column_names[0]])
train_x = keras.preprocessing.sequence.pad_sequences(train_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
train_y = train[column_names[1]]

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = K_FOLD)
history = {}
loss, accuracy, precision, recall, F1 = np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD)
id = 0
epochs = 10
test_x = token.texts_to_sequences(test[column_names[0]])
test_x = keras.preprocessing.sequence.pad_sequences(test_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
test_y = test[column_names[1]]
best_model = None
best_f1 = 0
best_id = 0
for train_index, val_index in kf.split(train_x, train_y):
    training_x, training_y = train_x[train_index], train_y.iloc[train_index]
    validation_x, validation_y = train_x[val_index], train_y.iloc[val_index]
    model = model_generator()
    history[id] = model.fit(x=training_x, y=training_y, validation_data=(validation_x, validation_y),
                                               epochs=epochs, batch_size=BATCH_SIZE)
    loss[id], accuracy[id], precision[id], recall[id] = model.evaluate(x=test_x, y=test_y)
    F1[id] = 2 * (precision[id] * recall[id]) / (precision[id] + recall[id])
    if F1[id] > best_f1:
        best_model = model
        best_f1 = F1[id]
        best_id = id
    id += 1
print("Best Model: Model_{}".format(best_id))
# Out:
# Epoch 1/10
# 46/46 [==============================] - 8s 26ms/step - loss: 0.4966 - accuracy: 0.8080 - precision: 0.8109 - recall: 0.9949 - val_loss: 0.4487 - val_accuracy: 0.8299 - val_precision: 0.8299 - val_recall: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.4539 - accuracy: 0.8087 - precision: 0.8124 - recall: 0.9932 - val_loss: 0.4626 - val_accuracy: 0.8299 - val_precision: 0.8299 - val_recall: 1.0000
# Epoch 3/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.3953 - accuracy: 0.8236 - precision: 0.8283 - recall: 0.9868 - val_loss: 0.4893 - val_accuracy: 0.8313 - val_precision: 0.8319 - val_recall: 0.9983
# Epoch 4/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.2849 - accuracy: 0.8699 - precision: 0.8842 - recall: 0.9658 - val_loss: 0.5172 - val_accuracy: 0.7690 - val_precision: 0.8639 - val_recall: 0.8567
# Epoch 5/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.1948 - accuracy: 0.9204 - precision: 0.9493 - recall: 0.9526 - val_loss: 0.5642 - val_accuracy: 0.7953 - val_precision: 0.8610 - val_recall: 0.8983
# Epoch 6/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.1501 - accuracy: 0.9447 - precision: 0.9682 - recall: 0.9633 - val_loss: 0.6059 - val_accuracy: 0.7981 - val_precision: 0.8603 - val_recall: 0.9033
# Epoch 7/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.1356 - accuracy: 0.9492 - precision: 0.9737 - recall: 0.9633 - val_loss: 0.6271 - val_accuracy: 0.7759 - val_precision: 0.8614 - val_recall: 0.8700
# Epoch 8/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1039 - accuracy: 0.9581 - precision: 0.9797 - recall: 0.9684 - val_loss: 0.6055 - val_accuracy: 0.8091 - val_precision: 0.8609 - val_recall: 0.9183
# Epoch 9/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0917 - accuracy: 0.9630 - precision: 0.9835 - recall: 0.9705 - val_loss: 0.7521 - val_accuracy: 0.8188 - val_precision: 0.8591 - val_recall: 0.9350
# Epoch 10/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0783 - accuracy: 0.9647 - precision: 0.9848 - recall: 0.9714 - val_loss: 0.8378 - val_accuracy: 0.8285 - val_precision: 0.8584 - val_recall: 0.9500
# 29/29 [==============================] - 0s 6ms/step - loss: 0.8294 - accuracy: 0.8208 - precision: 0.8460 - recall: 0.9539
# Epoch 1/10
# 46/46 [==============================] - 3s 30ms/step - loss: 0.4911 - accuracy: 0.8035 - precision_1: 0.8180 - recall_1: 0.9776 - val_loss: 0.5092 - val_accuracy: 0.7925 - val_precision_1: 0.7925 - val_recall_1: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 1s 11ms/step - loss: 0.4458 - accuracy: 0.8191 - precision_1: 0.8191 - recall_1: 1.0000 - val_loss: 0.5064 - val_accuracy: 0.7911 - val_precision_1: 0.7931 - val_recall_1: 0.9965
# Epoch 3/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.3942 - accuracy: 0.8302 - precision_1: 0.8332 - recall_1: 0.9911 - val_loss: 0.5219 - val_accuracy: 0.7939 - val_precision_1: 0.7936 - val_recall_1: 1.0000
# Epoch 4/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.3044 - accuracy: 0.8689 - precision_1: 0.8740 - recall_1: 0.9814 - val_loss: 0.5522 - val_accuracy: 0.7593 - val_precision_1: 0.8202 - val_recall_1: 0.8918
# Epoch 5/10
# 46/46 [==============================] - 1s 11ms/step - loss: 0.2026 - accuracy: 0.9114 - precision_1: 0.9360 - recall_1: 0.9573 - val_loss: 0.6319 - val_accuracy: 0.7469 - val_precision_1: 0.8250 - val_recall_1: 0.8639
# Epoch 6/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1483 - accuracy: 0.9450 - precision_1: 0.9662 - recall_1: 0.9666 - val_loss: 0.7904 - val_accuracy: 0.7842 - val_precision_1: 0.8233 - val_recall_1: 0.9267
# Epoch 7/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1335 - accuracy: 0.9485 - precision_1: 0.9731 - recall_1: 0.9637 - val_loss: 0.7384 - val_accuracy: 0.7898 - val_precision_1: 0.8305 - val_recall_1: 0.9232
# Epoch 8/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.1016 - accuracy: 0.9571 - precision_1: 0.9799 - recall_1: 0.9675 - val_loss: 0.7426 - val_accuracy: 0.7842 - val_precision_1: 0.8283 - val_recall_1: 0.9180
# Epoch 9/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0992 - accuracy: 0.9595 - precision_1: 0.9800 - recall_1: 0.9704 - val_loss: 0.8102 - val_accuracy: 0.7649 - val_precision_1: 0.8255 - val_recall_1: 0.8918
# Epoch 10/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0833 - accuracy: 0.9647 - precision_1: 0.9850 - recall_1: 0.9717 - val_loss: 0.8550 - val_accuracy: 0.7607 - val_precision_1: 0.8344 - val_recall_1: 0.8709
# 29/29 [==============================] - 0s 5ms/step - loss: 0.7201 - accuracy: 0.7909 - precision_1: 0.8663 - recall_1: 0.8792
# Epoch 1/10
# 46/46 [==============================] - 3s 26ms/step - loss: 0.4843 - accuracy: 0.8177 - precision_2: 0.8187 - recall_2: 0.9983 - val_loss: 0.5067 - val_accuracy: 0.7967 - val_precision_2: 0.7967 - val_recall_2: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.4514 - accuracy: 0.8181 - precision_2: 0.8181 - recall_2: 1.0000 - val_loss: 0.4905 - val_accuracy: 0.7967 - val_precision_2: 0.7967 - val_recall_2: 1.0000
# Epoch 3/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.3902 - accuracy: 0.8288 - precision_2: 0.8283 - recall_2: 0.9975 - val_loss: 0.4938 - val_accuracy: 0.7967 - val_precision_2: 0.8104 - val_recall_2: 0.9722
# Epoch 4/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.2637 - accuracy: 0.8876 - precision_2: 0.9038 - recall_2: 0.9653 - val_loss: 0.5373 - val_accuracy: 0.7566 - val_precision_2: 0.8344 - val_recall_2: 0.8663
# Epoch 5/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1641 - accuracy: 0.9412 - precision_2: 0.9633 - recall_2: 0.9649 - val_loss: 0.6856 - val_accuracy: 0.7925 - val_precision_2: 0.8277 - val_recall_2: 0.9340
# Epoch 6/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1380 - accuracy: 0.9505 - precision_2: 0.9712 - recall_2: 0.9683 - val_loss: 0.6848 - val_accuracy: 0.7925 - val_precision_2: 0.8349 - val_recall_2: 0.9219
# Epoch 7/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1001 - accuracy: 0.9599 - precision_2: 0.9787 - recall_2: 0.9721 - val_loss: 0.7607 - val_accuracy: 0.7552 - val_precision_2: 0.8364 - val_recall_2: 0.8611
# Epoch 8/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0924 - accuracy: 0.9623 - precision_2: 0.9829 - recall_2: 0.9708 - val_loss: 0.8009 - val_accuracy: 0.7925 - val_precision_2: 0.8381 - val_recall_2: 0.9167
# Epoch 9/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0749 - accuracy: 0.9668 - precision_2: 0.9826 - recall_2: 0.9767 - val_loss: 0.8335 - val_accuracy: 0.7842 - val_precision_2: 0.8420 - val_recall_2: 0.8976
# Epoch 10/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0711 - accuracy: 0.9692 - precision_2: 0.9843 - recall_2: 0.9780 - val_loss: 0.8844 - val_accuracy: 0.7690 - val_precision_2: 0.8472 - val_recall_2: 0.8663
# 29/29 [==============================] - 0s 5ms/step - loss: 0.8224 - accuracy: 0.7810 - precision_2: 0.8598 - recall_2: 0.8738
# Epoch 1/10
# 46/46 [==============================] - 4s 28ms/step - loss: 0.4899 - accuracy: 0.8104 - precision_3: 0.8134 - recall_3: 0.9953 - val_loss: 0.4809 - val_accuracy: 0.8147 - val_precision_3: 0.8147 - val_recall_3: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.4521 - accuracy: 0.8136 - precision_3: 0.8136 - recall_3: 1.0000 - val_loss: 0.5023 - val_accuracy: 0.8147 - val_precision_3: 0.8147 - val_recall_3: 1.0000
# Epoch 3/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.3911 - accuracy: 0.8291 - precision_3: 0.8323 - recall_3: 0.9894 - val_loss: 0.4886 - val_accuracy: 0.8064 - val_precision_3: 0.8193 - val_recall_3: 0.9779
# Epoch 4/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.2818 - accuracy: 0.8758 - precision_3: 0.8925 - recall_3: 0.9634 - val_loss: 0.5611 - val_accuracy: 0.8091 - val_precision_3: 0.8199 - val_recall_3: 0.9813
# Epoch 5/10
# 46/46 [==============================] - 1s 12ms/step - loss: 0.2043 - accuracy: 0.9194 - precision_3: 0.9384 - recall_3: 0.9643 - val_loss: 0.5735 - val_accuracy: 0.7538 - val_precision_3: 0.8454 - val_recall_3: 0.8540
# Epoch 6/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1408 - accuracy: 0.9481 - precision_3: 0.9689 - recall_3: 0.9673 - val_loss: 0.6668 - val_accuracy: 0.7165 - val_precision_3: 0.8556 - val_recall_3: 0.7844
# Epoch 7/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1192 - accuracy: 0.9543 - precision_3: 0.9760 - recall_3: 0.9677 - val_loss: 0.6848 - val_accuracy: 0.7815 - val_precision_3: 0.8426 - val_recall_3: 0.8998
# Epoch 8/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1088 - accuracy: 0.9575 - precision_3: 0.9781 - recall_3: 0.9694 - val_loss: 0.6565 - val_accuracy: 0.7759 - val_precision_3: 0.8494 - val_recall_3: 0.8812
# Epoch 9/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0903 - accuracy: 0.9651 - precision_3: 0.9833 - recall_3: 0.9736 - val_loss: 0.7256 - val_accuracy: 0.7704 - val_precision_3: 0.8484 - val_recall_3: 0.8744
# Epoch 10/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0925 - accuracy: 0.9613 - precision_3: 0.9782 - recall_3: 0.9741 - val_loss: 0.8196 - val_accuracy: 0.7649 - val_precision_3: 0.8440 - val_recall_3: 0.8727
# 29/29 [==============================] - 0s 6ms/step - loss: 0.7697 - accuracy: 0.7898 - precision_3: 0.8681 - recall_3: 0.8752
# Epoch 1/10
# 46/46 [==============================] - 4s 26ms/step - loss: 0.5006 - accuracy: 0.8084 - precision_4: 0.8084 - recall_4: 1.0000 - val_loss: 0.4433 - val_accuracy: 0.8352 - val_precision_4: 0.8352 - val_recall_4: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.4532 - accuracy: 0.8098 - precision_4: 0.8102 - recall_4: 0.9987 - val_loss: 0.4337 - val_accuracy: 0.8421 - val_precision_4: 0.8410 - val_recall_4: 1.0000
# Epoch 3/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.3731 - accuracy: 0.8413 - precision_4: 0.8489 - recall_4: 0.9778 - val_loss: 0.4313 - val_accuracy: 0.8393 - val_precision_4: 0.8504 - val_recall_4: 0.9801
# Epoch 4/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.2580 - accuracy: 0.8952 - precision_4: 0.9134 - recall_4: 0.9615 - val_loss: 0.5142 - val_accuracy: 0.8241 - val_precision_4: 0.8574 - val_recall_4: 0.9469
# Epoch 5/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1914 - accuracy: 0.9295 - precision_4: 0.9517 - recall_4: 0.9615 - val_loss: 0.5834 - val_accuracy: 0.8338 - val_precision_4: 0.8588 - val_recall_4: 0.9585
# Epoch 6/10
# 46/46 [==============================] - 0s 10ms/step - loss: 0.1450 - accuracy: 0.9443 - precision_4: 0.9714 - recall_4: 0.9594 - val_loss: 0.5661 - val_accuracy: 0.7784 - val_precision_4: 0.8625 - val_recall_4: 0.8740
# Epoch 7/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.1182 - accuracy: 0.9523 - precision_4: 0.9791 - recall_4: 0.9615 - val_loss: 0.6425 - val_accuracy: 0.8227 - val_precision_4: 0.8561 - val_recall_4: 0.9469
# Epoch 8/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.1067 - accuracy: 0.9575 - precision_4: 0.9801 - recall_4: 0.9671 - val_loss: 0.6456 - val_accuracy: 0.8227 - val_precision_4: 0.8615 - val_recall_4: 0.9386
# Epoch 9/10
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0912 - accuracy: 0.9602 - precision_4: 0.9831 - recall_4: 0.9675 - val_loss: 0.7119 - val_accuracy: 0.8033 - val_precision_4: 0.8596 - val_recall_4: 0.9138
# Epoch 10/10
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0837 - accuracy: 0.9620 - precision_4: 0.9793 - recall_4: 0.9735 - val_loss: 0.7215 - val_accuracy: 0.8227 - val_precision_4: 0.8593 - val_recall_4: 0.9420
# 29/29 [==============================] - 0s 5ms/step - loss: 0.7367 - accuracy: 0.8119 - precision_4: 0.8462 - recall_4: 0.9403
# Best Model: Model_0

# %%
from matplotlib import pyplot as plt

# %%
plt.title('model training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model training accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['accuracy'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_accuracy'], label="model_{}".format(key))
plt.legend()

# %%
print("Loss: {}, Accuracy: {}, Precision: {}, Recall: {}, F1 Score: {}".format(
    np.average(loss), np.average(accuracy), np.average(precision), np.average(recall), np.average(F1)
))
# Out:
# Loss: 0.7756555914878845, Accuracy: 0.7988938093185425, Precision: 0.8572696328163147, Recall: 0.9044776082038879, F1 Score: 0.8797068983868398

# %%
best_model.save("Hybrid_FNC")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Hybrid_FNC\assets
# INFO:tensorflow:Assets written to: Hybrid_FNC\assets
