# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import numpy as np

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4082003400084523318
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3643801600
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6221942461748898120
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
# MAX_VNUM = 20000
SEQUENCE_LENGTH = 300
EMBED_DIMENSION = 100
BATCH_SIZE = 64
K_FOLD = 5

# %%
column_names = ["lemmatized_clean_final_article", "labels"]
data = pd.read_csv("../Preprocessed_Dataset/fnc-1_Preprocessed_Data.csv", encoding='utf-8', encoding_errors='ignore')[column_names]
train, test = train_test_split(data, test_size=0.2)

# %%
token = keras.preprocessing.text.Tokenizer()
token.fit_on_texts(data[column_names[0]])
vocab_size = len(token.word_index) + 2

# %%
embedding_vector = {}
f = open('../data/glove.6B.100d.txt')
for line in tqdm(f):
    word, coefs = line.split(maxsplit=1)
    coefs = np.fromstring(coefs, "f", sep=" ")
    embedding_vector[word] = coefs
embedding_matrix = np.zeros((vocab_size, EMBED_DIMENSION))
for word,i in tqdm(token.word_index.items()):
    embedding_value = embedding_vector.get(word)
    if embedding_value is not None:
        embedding_matrix[i] = embedding_value
# Out:
# 400000it [00:09, 41481.93it/s]
# 100%|██████████| 17539/17539 [00:00<00:00, 1708761.65it/s]

# %% [markdown]
# ### Model

# %%
def model_generator():
    model = keras.models.Sequential()
    model.add(layers.Embedding(input_dim=vocab_size, output_dim=EMBED_DIMENSION, 
                        embeddings_initializer=keras.initializers.Constant(embedding_matrix), 
                        input_length=SEQUENCE_LENGTH, trainable = False))
    # model.add(layers.Permute((2, 1)))
    # model.add(layers.Conv1D(128, 5, activation='relu', name="Conv1D"))
    # model.add(layers.MaxPooling1D(pool_size=2, name="MaxPooling1D"))
    model.add(layers.LSTM(32, 
                        #   activation=None, 
                          name="LSTM"))
    model.add(layers.Dense(1, activation="sigmoid"))
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=[
        "accuracy",
        tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
    ])
    return model

# %%
train_x = token.texts_to_sequences(train[column_names[0]])
train_x = keras.preprocessing.sequence.pad_sequences(train_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
train_y = train[column_names[1]]

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = K_FOLD)
history = {}
loss, accuracy, precision, recall, F1 = np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD)
id = 0
epochs = 10
test_x = token.texts_to_sequences(test[column_names[0]])
test_x = keras.preprocessing.sequence.pad_sequences(test_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
test_y = test[column_names[1]]
best_model = None
best_f1 = 0
best_id = 0
for train_index, val_index in kf.split(train_x, train_y):
    training_x, training_y = train_x[train_index], train_y.iloc[train_index]
    validation_x, validation_y = train_x[val_index], train_y.iloc[val_index]
    model = model_generator()
    history[id] = model.fit(x=training_x, y=training_y, validation_data=(validation_x, validation_y),
                                               epochs=epochs, batch_size=BATCH_SIZE)
    loss[id], accuracy[id], precision[id], recall[id] = model.evaluate(x=test_x, y=test_y)
    F1[id] = 2 * (precision[id] * recall[id]) / (precision[id] + recall[id])
    if F1[id] > best_f1:
        best_model = model
        best_f1 = F1[id]
        best_id = id
    id += 1
print("Best Model: Model_{}".format(best_id))
# Out:
# Epoch 1/10
# 46/46 [==============================] - 10s 35ms/step - loss: 0.5732 - accuracy: 0.7938 - precision: 0.8084 - recall: 0.9765 - val_loss: 0.4501 - val_accuracy: 0.8313 - val_precision: 0.8313 - val_recall: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4874 - accuracy: 0.8084 - precision: 0.8084 - recall: 1.0000 - val_loss: 0.4515 - val_accuracy: 0.8313 - val_precision: 0.8313 - val_recall: 1.0000
# Epoch 3/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4863 - accuracy: 0.8084 - precision: 0.8084 - recall: 1.0000 - val_loss: 0.4513 - val_accuracy: 0.8313 - val_precision: 0.8313 - val_recall: 1.0000
# Epoch 4/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4852 - accuracy: 0.8084 - precision: 0.8084 - recall: 1.0000 - val_loss: 0.4547 - val_accuracy: 0.8313 - val_precision: 0.8313 - val_recall: 1.0000
# Epoch 5/10
# 46/46 [==============================] - 1s 19ms/step - loss: 0.4831 - accuracy: 0.8084 - precision: 0.8084 - recall: 1.0000 - val_loss: 0.4483 - val_accuracy: 0.8326 - val_precision: 0.8324 - val_recall: 1.0000
# Epoch 6/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4826 - accuracy: 0.8094 - precision: 0.8092 - recall: 1.0000 - val_loss: 0.4465 - val_accuracy: 0.8326 - val_precision: 0.8324 - val_recall: 1.0000
# Epoch 7/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4802 - accuracy: 0.8087 - precision: 0.8104 - recall: 0.9966 - val_loss: 0.4470 - val_accuracy: 0.8354 - val_precision: 0.8347 - val_recall: 1.0000
# Epoch 8/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4812 - accuracy: 0.8098 - precision: 0.8114 - recall: 0.9961 - val_loss: 0.4531 - val_accuracy: 0.8313 - val_precision: 0.8313 - val_recall: 1.0000
# Epoch 9/10
# 46/46 [==============================] - 1s 17ms/step - loss: 0.4804 - accuracy: 0.8125 - precision: 0.8126 - recall: 0.9983 - val_loss: 0.4470 - val_accuracy: 0.8326 - val_precision: 0.8324 - val_recall: 1.0000
# Epoch 10/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4776 - accuracy: 0.8115 - precision: 0.8128 - recall: 0.9961 - val_loss: 0.4437 - val_accuracy: 0.8382 - val_precision: 0.8389 - val_recall: 0.9967
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4666 - accuracy: 0.8230 - precision: 0.8237 - recall: 0.9973
# Epoch 1/10
# 46/46 [==============================] - 3s 31ms/step - loss: 0.5614 - accuracy: 0.8011 - precision_1: 0.8114 - recall_1: 0.9838 - val_loss: 0.4740 - val_accuracy: 0.8160 - val_precision_1: 0.8160 - val_recall_1: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4811 - accuracy: 0.8122 - precision_1: 0.8122 - recall_1: 1.0000 - val_loss: 0.4735 - val_accuracy: 0.8160 - val_precision_1: 0.8160 - val_recall_1: 1.0000
# Epoch 3/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4813 - accuracy: 0.8122 - precision_1: 0.8122 - recall_1: 1.0000 - val_loss: 0.4722 - val_accuracy: 0.8160 - val_precision_1: 0.8160 - val_recall_1: 1.0000
# Epoch 4/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4807 - accuracy: 0.8125 - precision_1: 0.8125 - recall_1: 1.0000 - val_loss: 0.4705 - val_accuracy: 0.8160 - val_precision_1: 0.8160 - val_recall_1: 1.0000
# Epoch 5/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4799 - accuracy: 0.8129 - precision_1: 0.8127 - recall_1: 1.0000 - val_loss: 0.4697 - val_accuracy: 0.8160 - val_precision_1: 0.8160 - val_recall_1: 1.0000
# Epoch 6/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4773 - accuracy: 0.8129 - precision_1: 0.8127 - recall_1: 1.0000 - val_loss: 0.4705 - val_accuracy: 0.8160 - val_precision_1: 0.8160 - val_recall_1: 1.0000
# Epoch 7/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4770 - accuracy: 0.8136 - precision_1: 0.8135 - recall_1: 0.9996 - val_loss: 0.4715 - val_accuracy: 0.8160 - val_precision_1: 0.8160 - val_recall_1: 1.0000
# Epoch 8/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4757 - accuracy: 0.8146 - precision_1: 0.8141 - recall_1: 1.0000 - val_loss: 0.4678 - val_accuracy: 0.8174 - val_precision_1: 0.8172 - val_recall_1: 1.0000
# Epoch 9/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4746 - accuracy: 0.8149 - precision_1: 0.8162 - recall_1: 0.9966 - val_loss: 0.4671 - val_accuracy: 0.8174 - val_precision_1: 0.8172 - val_recall_1: 1.0000
# Epoch 10/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4728 - accuracy: 0.8146 - precision_1: 0.8159 - recall_1: 0.9966 - val_loss: 0.4641 - val_accuracy: 0.8147 - val_precision_1: 0.8175 - val_recall_1: 0.9949
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4668 - accuracy: 0.8208 - precision_1: 0.8218 - recall_1: 0.9973
# Epoch 1/10
# 46/46 [==============================] - 3s 30ms/step - loss: 0.5611 - accuracy: 0.8084 - precision_2: 0.8167 - recall_2: 0.9869 - val_loss: 0.5092 - val_accuracy: 0.7967 - val_precision_2: 0.7967 - val_recall_2: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4756 - accuracy: 0.8170 - precision_2: 0.8170 - recall_2: 1.0000 - val_loss: 0.5022 - val_accuracy: 0.7967 - val_precision_2: 0.7967 - val_recall_2: 1.0000
# Epoch 3/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4746 - accuracy: 0.8170 - precision_2: 0.8170 - recall_2: 1.0000 - val_loss: 0.5022 - val_accuracy: 0.7967 - val_precision_2: 0.7967 - val_recall_2: 1.0000
# Epoch 4/10
# 46/46 [==============================] - 1s 17ms/step - loss: 0.4741 - accuracy: 0.8170 - precision_2: 0.8170 - recall_2: 1.0000 - val_loss: 0.5007 - val_accuracy: 0.7967 - val_precision_2: 0.7967 - val_recall_2: 1.0000
# Epoch 5/10
# 46/46 [==============================] - 1s 17ms/step - loss: 0.4736 - accuracy: 0.8170 - precision_2: 0.8170 - recall_2: 1.0000 - val_loss: 0.5021 - val_accuracy: 0.7967 - val_precision_2: 0.7967 - val_recall_2: 1.0000
# Epoch 6/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4745 - accuracy: 0.8170 - precision_2: 0.8170 - recall_2: 1.0000 - val_loss: 0.4995 - val_accuracy: 0.7967 - val_precision_2: 0.7967 - val_recall_2: 1.0000
# Epoch 7/10
# 46/46 [==============================] - 1s 19ms/step - loss: 0.4740 - accuracy: 0.8170 - precision_2: 0.8170 - recall_2: 1.0000 - val_loss: 0.5034 - val_accuracy: 0.7967 - val_precision_2: 0.7967 - val_recall_2: 1.0000
# Epoch 8/10
# 46/46 [==============================] - 1s 19ms/step - loss: 0.4729 - accuracy: 0.8170 - precision_2: 0.8170 - recall_2: 1.0000 - val_loss: 0.4987 - val_accuracy: 0.7967 - val_precision_2: 0.7967 - val_recall_2: 1.0000
# Epoch 9/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4735 - accuracy: 0.8170 - precision_2: 0.8170 - recall_2: 1.0000 - val_loss: 0.5027 - val_accuracy: 0.7967 - val_precision_2: 0.7967 - val_recall_2: 1.0000
# Epoch 10/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4717 - accuracy: 0.8174 - precision_2: 0.8173 - recall_2: 1.0000 - val_loss: 0.4984 - val_accuracy: 0.7981 - val_precision_2: 0.7978 - val_recall_2: 1.0000
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4705 - accuracy: 0.8186 - precision_2: 0.8186 - recall_2: 1.0000
# Epoch 1/10
# 46/46 [==============================] - 3s 31ms/step - loss: 0.5708 - accuracy: 0.7928 - precision_3: 0.8104 - recall_3: 0.9718 - val_loss: 0.4730 - val_accuracy: 0.8216 - val_precision_3: 0.8216 - val_recall_3: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4830 - accuracy: 0.8108 - precision_3: 0.8108 - recall_3: 1.0000 - val_loss: 0.4706 - val_accuracy: 0.8216 - val_precision_3: 0.8216 - val_recall_3: 1.0000
# Epoch 3/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4826 - accuracy: 0.8108 - precision_3: 0.8108 - recall_3: 1.0000 - val_loss: 0.4687 - val_accuracy: 0.8216 - val_precision_3: 0.8216 - val_recall_3: 1.0000
# Epoch 4/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4826 - accuracy: 0.8108 - precision_3: 0.8108 - recall_3: 1.0000 - val_loss: 0.4702 - val_accuracy: 0.8216 - val_precision_3: 0.8216 - val_recall_3: 1.0000
# Epoch 5/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4823 - accuracy: 0.8108 - precision_3: 0.8108 - recall_3: 1.0000 - val_loss: 0.4702 - val_accuracy: 0.8216 - val_precision_3: 0.8216 - val_recall_3: 1.0000
# Epoch 6/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4815 - accuracy: 0.8108 - precision_3: 0.8108 - recall_3: 1.0000 - val_loss: 0.4721 - val_accuracy: 0.8216 - val_precision_3: 0.8216 - val_recall_3: 1.0000
# Epoch 7/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4815 - accuracy: 0.8108 - precision_3: 0.8108 - recall_3: 1.0000 - val_loss: 0.4681 - val_accuracy: 0.8216 - val_precision_3: 0.8216 - val_recall_3: 1.0000
# Epoch 8/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4802 - accuracy: 0.8111 - precision_3: 0.8111 - recall_3: 1.0000 - val_loss: 0.4673 - val_accuracy: 0.8216 - val_precision_3: 0.8216 - val_recall_3: 1.0000
# Epoch 9/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4800 - accuracy: 0.8118 - precision_3: 0.8116 - recall_3: 1.0000 - val_loss: 0.4656 - val_accuracy: 0.8243 - val_precision_3: 0.8239 - val_recall_3: 1.0000
# Epoch 10/10
# 46/46 [==============================] - 1s 19ms/step - loss: 0.4779 - accuracy: 0.8122 - precision_3: 0.8123 - recall_3: 0.9991 - val_loss: 0.4678 - val_accuracy: 0.8216 - val_precision_3: 0.8252 - val_recall_3: 0.9933
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4741 - accuracy: 0.8164 - precision_3: 0.8225 - recall_3: 0.9892
# Epoch 1/10
# 46/46 [==============================] - 3s 29ms/step - loss: 0.5744 - accuracy: 0.8091 - precision_4: 0.8161 - recall_4: 0.9890 - val_loss: 0.5144 - val_accuracy: 0.7992 - val_precision_4: 0.7992 - val_recall_4: 1.0000
# Epoch 2/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4753 - accuracy: 0.8164 - precision_4: 0.8164 - recall_4: 1.0000 - val_loss: 0.5017 - val_accuracy: 0.7992 - val_precision_4: 0.7992 - val_recall_4: 1.0000
# Epoch 3/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4729 - accuracy: 0.8164 - precision_4: 0.8164 - recall_4: 1.0000 - val_loss: 0.5011 - val_accuracy: 0.7992 - val_precision_4: 0.7992 - val_recall_4: 1.0000
# Epoch 4/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4710 - accuracy: 0.8167 - precision_4: 0.8167 - recall_4: 1.0000 - val_loss: 0.5024 - val_accuracy: 0.7992 - val_precision_4: 0.7992 - val_recall_4: 1.0000
# Epoch 5/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4693 - accuracy: 0.8181 - precision_4: 0.8178 - recall_4: 1.0000 - val_loss: 0.5026 - val_accuracy: 0.8006 - val_precision_4: 0.8003 - val_recall_4: 1.0000
# Epoch 6/10
# 46/46 [==============================] - 1s 19ms/step - loss: 0.4690 - accuracy: 0.8174 - precision_4: 0.8186 - recall_4: 0.9975 - val_loss: 0.5024 - val_accuracy: 0.7992 - val_precision_4: 0.7992 - val_recall_4: 1.0000
# Epoch 7/10
# 46/46 [==============================] - 1s 18ms/step - loss: 0.4666 - accuracy: 0.8157 - precision_4: 0.8196 - recall_4: 0.9928 - val_loss: 0.5087 - val_accuracy: 0.7895 - val_precision_4: 0.8040 - val_recall_4: 0.9740
# Epoch 8/10
# 46/46 [==============================] - 1s 19ms/step - loss: 0.4677 - accuracy: 0.8178 - precision_4: 0.8182 - recall_4: 0.9987 - val_loss: 0.4995 - val_accuracy: 0.7992 - val_precision_4: 0.7992 - val_recall_4: 1.0000
# Epoch 9/10
# 46/46 [==============================] - 1s 23ms/step - loss: 0.4647 - accuracy: 0.8202 - precision_4: 0.8202 - recall_4: 0.9987 - val_loss: 0.4964 - val_accuracy: 0.8019 - val_precision_4: 0.8022 - val_recall_4: 0.9983
# Epoch 10/10
# 46/46 [==============================] - 1s 21ms/step - loss: 0.4634 - accuracy: 0.8198 - precision_4: 0.8219 - recall_4: 0.9949 - val_loss: 0.4983 - val_accuracy: 0.8033 - val_precision_4: 0.8059 - val_recall_4: 0.9931
# 29/29 [==============================] - 0s 9ms/step - loss: 0.4691 - accuracy: 0.8208 - precision_4: 0.8247 - recall_4: 0.9919
# Best Model: Model_0

# %%
from matplotlib import pyplot as plt

# %%
plt.title('model training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model training accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['accuracy'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_accuracy'], label="model_{}".format(key))
plt.legend()

# %%
print("Loss: {}, Accuracy: {}, Precision: {}, Recall: {}, F1 Score: {}".format(
    np.average(loss), np.average(accuracy), np.average(precision), np.average(recall), np.average(F1)
))
# Out:
# Loss: 0.46940442323684695, Accuracy: 0.819911515712738, Precision: 0.8222524166107178, Recall: 0.9951351404190063, F1 Score: 0.9004631440024182

# %%
best_model.save("RNN_FNC")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: RNN_FNC\assets
# INFO:tensorflow:Assets written to: RNN_FNC\assets
