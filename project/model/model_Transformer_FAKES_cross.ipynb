# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import numpy as np

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13670916348718788517
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3643801600
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8625174270871245341
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
# MAX_VNUM = 20000
SEQUENCE_LENGTH = 300
EMBED_DIMENSION = 100
BATCH_SIZE = 64
K_FOLD = 5
NUM_HEADS = 4
FF_DIMENSION = 32

# %%
column_names = ["lemmatized_clean_final_article", "labels"]
data = pd.read_csv("../Preprocessed_Dataset/Fakes_Preprocessed_Data.csv", encoding='utf-8', encoding_errors='ignore')[column_names]
train, test = train_test_split(data, test_size=0.2)

# %%
token = keras.preprocessing.text.Tokenizer()
token.fit_on_texts(data[column_names[0]])
vocab_size = len(token.word_index) + 2

# %%
embedding_vector = {}
f = open('../data/glove.6B.100d.txt')
for line in tqdm(f):
    word, coefs = line.split(maxsplit=1)
    coefs = np.fromstring(coefs, "f", sep=" ")
    embedding_vector[word] = coefs
embedding_matrix = np.zeros((vocab_size, EMBED_DIMENSION))
for word,i in tqdm(token.word_index.items()):
    embedding_value = embedding_vector.get(word)
    if embedding_value is not None:
        embedding_matrix[i] = embedding_value
# Out:
# 400000it [00:08, 44627.33it/s]
# 100%|██████████| 10014/10014 [00:00<00:00, 1736183.87it/s]

# %% [markdown]
# ### Model

# %%
class MultiHeadSelfAttention(layers.Layer):
    def __init__(self, embed_dim, num_heads=8):
        super(MultiHeadSelfAttention, self).__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        if embed_dim % num_heads !=0:
             raise ValueError(
                f"embedding dimension = {embed_dim} should be divisible by number of heads = {num_heads}"
            )
        self.projection_dim = embed_dim // num_heads
        self.query_dense = layers.Dense(embed_dim)
        self.key_dense = layers.Dense(embed_dim)
        self.value_dense = layers.Dense(embed_dim)
        self.combine_heads = layers.Dense(embed_dim)
    
    def attention(self, query, key, value):
        score = tf.matmul(query, key, transpose_b = True)
        dim_key = tf.cast(tf.shape(key)[-1], tf.float32)
        scaled_score = score / tf.math.sqrt(dim_key)
        weights = tf.nn.softmax(scaled_score, axis=-1)
        output = tf.matmul(weights, value)
        return output, weights
    
    def seperate_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim))
        return tf.transpose(x, perm = [0, 2, 1, 3])
    
    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        query = self.query_dense(inputs)
        key = self.key_dense(inputs)
        value = self.value_dense(inputs)
        
        query = self.seperate_heads(query, batch_size)
        key = self.seperate_heads(key, batch_size)
        value = self.seperate_heads(value, batch_size)
        
        attention, weights = self.attention(query, key, value)
        
        attention = tf.transpose(attention, perm=[0,2,1,3])
        
        concat_attention = tf.reshape(attention, (batch_size, -1, self.embed_dim))
        
        output = self.combine_heads(concat_attention)
        
        return output

# %%
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.embedding = layers.Embedding(
            input_dim=embedding_matrix.shape[0],
            output_dim=embedding_matrix.shape[1],
            weights=[embedding_matrix],
            input_length=SEQUENCE_LENGTH,
            trainable=False  # Set to False to keep the pre-trained embeddings fixed
        )
        self.att = MultiHeadSelfAttention(embed_dim, num_heads)
        self.ffn = keras.Sequential(
            [layers.Dense(ff_dim, activation='relu'), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)
    
    def call(self, inputs, training):
        attn_output = self.att(inputs)
        attn_output = self.dropout1(attn_output, training = training)
        
        out1 = self.layernorm1(inputs + attn_output)
        
        ffn_output = self.ffn(out1)
        
        fnn_output = self.dropout2(ffn_output, training = training)
        return self.layernorm2(out1 + ffn_output)

# %%
class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = layers.Embedding(input_dim = vocab_size, output_dim = embed_dim)
        self.pos_emb = layers.Embedding(input_dim = maxlen, output_dim = embed_dim)
    
    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit = maxlen, delta=1)
        positions = self.pos_emb(positions)
        
        x = self.token_emb(x)
        
        return x + positions

# %%
def model_generator():
    inputs = layers.Input(shape = (SEQUENCE_LENGTH,))
    embedding_layer = TokenAndPositionEmbedding(SEQUENCE_LENGTH, vocab_size, EMBED_DIMENSION)
    x = embedding_layer(inputs)
    transformer_block = TransformerBlock(EMBED_DIMENSION, NUM_HEADS, FF_DIMENSION)

    x = transformer_block(x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.1)(x)
    x = layers.Dense(10, activation='relu')(x)
    x = layers.Dropout(0.1)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = keras.Model(inputs = inputs, outputs = outputs)
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy',tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])
    return model

# %%
train_x = token.texts_to_sequences(train[column_names[0]])
train_x = keras.preprocessing.sequence.pad_sequences(train_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
train_y = train[column_names[1]]

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = K_FOLD)
history = {}
loss, accuracy, precision, recall, F1 = np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD)
id = 0
epochs = 10
test_x = token.texts_to_sequences(test[column_names[0]])
test_x = keras.preprocessing.sequence.pad_sequences(test_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
test_y = test[column_names[1]]
best_model = None
best_f1 = 0
best_id = 0
for train_index, val_index in kf.split(train_x, train_y):
    training_x, training_y = train_x[train_index], train_y.iloc[train_index]
    validation_x, validation_y = train_x[val_index], train_y.iloc[val_index]
    model = model_generator()
    history[id] = model.fit(x=training_x, y=training_y, validation_data=(validation_x, validation_y),
                                               epochs=epochs, batch_size=BATCH_SIZE)
    loss[id], accuracy[id], precision[id], recall[id] = model.evaluate(x=test_x, y=test_y)
    F1[id] = 2 * (precision[id] * recall[id]) / (precision[id] + recall[id])
    if F1[id] > best_f1:
        best_model = model
        best_f1 = F1[id]
        best_id = id
    id += 1
print("Best Model: Model_{}".format(best_id))
# Out:
# Epoch 1/10
# 9/9 [==============================] - 4s 88ms/step - loss: 0.7215 - accuracy: 0.5019 - precision: 0.5280 - recall: 0.7148 - val_loss: 0.7075 - val_accuracy: 0.5271 - val_precision: 0.5271 - val_recall: 1.0000
# Epoch 2/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.7044 - accuracy: 0.5292 - precision: 0.5370 - recall: 0.9170 - val_loss: 0.6951 - val_accuracy: 0.5194 - val_precision: 0.5294 - val_recall: 0.7941
# Epoch 3/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6903 - accuracy: 0.5292 - precision: 0.6357 - recall: 0.2960 - val_loss: 0.6932 - val_accuracy: 0.4729 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6932 - accuracy: 0.4650 - precision: 0.5385 - recall: 0.0505 - val_loss: 0.6932 - val_accuracy: 0.4729 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6925 - accuracy: 0.5272 - precision: 0.5373 - recall: 0.8845 - val_loss: 0.6931 - val_accuracy: 0.5271 - val_precision: 0.5271 - val_recall: 1.0000
# Epoch 6/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6928 - accuracy: 0.5389 - precision: 0.5389 - recall: 1.0000 - val_loss: 0.6930 - val_accuracy: 0.5271 - val_precision: 0.5271 - val_recall: 1.0000
# Epoch 7/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6932 - accuracy: 0.5389 - precision: 0.5389 - recall: 1.0000 - val_loss: 0.6931 - val_accuracy: 0.5271 - val_precision: 0.5271 - val_recall: 1.0000
# Epoch 8/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6919 - accuracy: 0.5389 - precision: 0.5389 - recall: 1.0000 - val_loss: 0.6929 - val_accuracy: 0.5271 - val_precision: 0.5271 - val_recall: 1.0000
# Epoch 9/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6905 - accuracy: 0.5389 - precision: 0.5389 - recall: 1.0000 - val_loss: 0.6951 - val_accuracy: 0.5271 - val_precision: 0.5271 - val_recall: 1.0000
# Epoch 10/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6881 - accuracy: 0.5389 - precision: 0.5389 - recall: 1.0000 - val_loss: 0.6917 - val_accuracy: 0.5271 - val_precision: 0.5271 - val_recall: 1.0000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6940 - accuracy: 0.5031 - precision: 0.5031 - recall: 1.0000
# Epoch 1/10
# 9/9 [==============================] - 2s 88ms/step - loss: 0.7143 - accuracy: 0.4903 - precision_1: 0.5014 - recall_1: 0.6844 - val_loss: 0.6840 - val_accuracy: 0.6279 - val_precision_1: 0.6371 - val_recall_1: 0.9634
# Epoch 2/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6858 - accuracy: 0.5603 - precision_1: 0.5552 - recall_1: 0.7072 - val_loss: 0.7069 - val_accuracy: 0.3798 - val_precision_1: 1.0000 - val_recall_1: 0.0244
# Epoch 3/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.7126 - accuracy: 0.4903 - precision_1: 0.5185 - recall_1: 0.0532 - val_loss: 0.6823 - val_accuracy: 0.5969 - val_precision_1: 0.6339 - val_recall_1: 0.8659
# Epoch 4/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6859 - accuracy: 0.5350 - precision_1: 0.5254 - recall_1: 0.9430 - val_loss: 0.6739 - val_accuracy: 0.6357 - val_precision_1: 0.6357 - val_recall_1: 1.0000
# Epoch 5/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6740 - accuracy: 0.5078 - precision_1: 0.5098 - recall_1: 0.9886 - val_loss: 0.6798 - val_accuracy: 0.6357 - val_precision_1: 0.6357 - val_recall_1: 1.0000
# Epoch 6/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6620 - accuracy: 0.5272 - precision_1: 0.5202 - recall_1: 0.9772 - val_loss: 0.6577 - val_accuracy: 0.6357 - val_precision_1: 0.6357 - val_recall_1: 1.0000
# Epoch 7/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6410 - accuracy: 0.6362 - precision_1: 0.6016 - recall_1: 0.8555 - val_loss: 0.6599 - val_accuracy: 0.6202 - val_precision_1: 0.6387 - val_recall_1: 0.9268
# Epoch 8/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.5754 - accuracy: 0.7043 - precision_1: 0.7063 - recall_1: 0.7224 - val_loss: 0.6582 - val_accuracy: 0.5891 - val_precision_1: 0.6239 - val_recall_1: 0.8902
# Epoch 9/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4824 - accuracy: 0.7626 - precision_1: 0.7582 - recall_1: 0.7871 - val_loss: 0.7591 - val_accuracy: 0.4341 - val_precision_1: 0.6098 - val_recall_1: 0.3049
# Epoch 10/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4053 - accuracy: 0.8171 - precision_1: 0.8789 - recall_1: 0.7452 - val_loss: 0.7481 - val_accuracy: 0.6202 - val_precision_1: 0.6410 - val_recall_1: 0.9146
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8929 - accuracy: 0.4907 - precision_1: 0.4964 - recall_1: 0.8395
# Epoch 1/10
# 9/9 [==============================] - 2s 108ms/step - loss: 0.7007 - accuracy: 0.4844 - precision_2: 0.5299 - recall_2: 0.4750 - val_loss: 0.6947 - val_accuracy: 0.4651 - val_precision_2: 0.4756 - val_recall_2: 0.6000
# Epoch 2/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6894 - accuracy: 0.5233 - precision_2: 0.6129 - recall_2: 0.3393 - val_loss: 0.6907 - val_accuracy: 0.5194 - val_precision_2: 0.5155 - val_recall_2: 0.7692
# Epoch 3/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6762 - accuracy: 0.5623 - precision_2: 0.5629 - recall_2: 0.8786 - val_loss: 0.7079 - val_accuracy: 0.5039 - val_precision_2: 0.5039 - val_recall_2: 1.0000
# Epoch 4/10
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6710 - accuracy: 0.5447 - precision_2: 0.5481 - recall_2: 0.9357 - val_loss: 0.6984 - val_accuracy: 0.5039 - val_precision_2: 0.5039 - val_recall_2: 1.0000
# Epoch 5/10
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6493 - accuracy: 0.5700 - precision_2: 0.5616 - recall_2: 0.9607 - val_loss: 0.6957 - val_accuracy: 0.4961 - val_precision_2: 0.5000 - val_recall_2: 0.9538
# Epoch 6/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6057 - accuracy: 0.7160 - precision_2: 0.6754 - recall_2: 0.9214 - val_loss: 0.7093 - val_accuracy: 0.5039 - val_precision_2: 0.5044 - val_recall_2: 0.8769
# Epoch 7/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5627 - accuracy: 0.7412 - precision_2: 0.8551 - recall_2: 0.6321 - val_loss: 0.8691 - val_accuracy: 0.4806 - val_precision_2: 0.4921 - val_recall_2: 0.9538
# Epoch 8/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.5277 - accuracy: 0.6868 - precision_2: 0.6755 - recall_2: 0.8179 - val_loss: 0.7595 - val_accuracy: 0.4574 - val_precision_2: 0.4699 - val_recall_2: 0.6000
# Epoch 9/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4541 - accuracy: 0.7743 - precision_2: 0.7500 - recall_2: 0.8786 - val_loss: 0.7635 - val_accuracy: 0.5349 - val_precision_2: 0.5439 - val_recall_2: 0.4769
# Epoch 10/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4000 - accuracy: 0.8249 - precision_2: 0.8025 - recall_2: 0.9000 - val_loss: 0.7952 - val_accuracy: 0.5116 - val_precision_2: 0.5192 - val_recall_2: 0.4154
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8232 - accuracy: 0.5155 - precision_2: 0.5238 - recall_2: 0.4074
# Epoch 1/10
# 9/9 [==============================] - 2s 65ms/step - loss: 0.7054 - accuracy: 0.5495 - precision_3: 0.5759 - recall_3: 0.6500 - val_loss: 0.7471 - val_accuracy: 0.5156 - val_precision_3: 0.5556 - val_recall_3: 0.2308
# Epoch 2/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.7419 - accuracy: 0.5359 - precision_3: 0.5837 - recall_3: 0.5107 - val_loss: 0.7224 - val_accuracy: 0.5078 - val_precision_3: 0.5078 - val_recall_3: 1.0000
# Epoch 3/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6988 - accuracy: 0.5398 - precision_3: 0.5419 - recall_3: 0.9929 - val_loss: 0.7000 - val_accuracy: 0.5078 - val_precision_3: 0.5078 - val_recall_3: 1.0000
# Epoch 4/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6813 - accuracy: 0.5495 - precision_3: 0.5484 - recall_3: 0.9714 - val_loss: 0.6974 - val_accuracy: 0.5078 - val_precision_3: 0.5078 - val_recall_3: 1.0000
# Epoch 5/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6731 - accuracy: 0.5476 - precision_3: 0.5464 - recall_3: 0.9893 - val_loss: 0.7067 - val_accuracy: 0.5078 - val_precision_3: 0.5078 - val_recall_3: 1.0000
# Epoch 6/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6677 - accuracy: 0.6350 - precision_3: 0.6192 - recall_3: 0.8536 - val_loss: 0.6960 - val_accuracy: 0.4922 - val_precision_3: 0.5000 - val_recall_3: 0.9231
# Epoch 7/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6522 - accuracy: 0.6058 - precision_3: 0.5842 - recall_3: 0.9536 - val_loss: 0.7107 - val_accuracy: 0.5234 - val_precision_3: 0.5204 - val_recall_3: 0.7846
# Epoch 8/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6244 - accuracy: 0.6544 - precision_3: 0.6378 - recall_3: 0.8429 - val_loss: 0.7040 - val_accuracy: 0.5156 - val_precision_3: 0.5176 - val_recall_3: 0.6769
# Epoch 9/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5606 - accuracy: 0.7359 - precision_3: 0.6827 - recall_3: 0.9607 - val_loss: 0.7326 - val_accuracy: 0.4453 - val_precision_3: 0.4483 - val_recall_3: 0.4000
# Epoch 10/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4818 - accuracy: 0.8058 - precision_3: 0.8041 - recall_3: 0.8500 - val_loss: 0.7821 - val_accuracy: 0.5078 - val_precision_3: 0.5278 - val_recall_3: 0.2923
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7315 - accuracy: 0.5466 - precision_3: 0.5870 - recall_3: 0.3333
# Epoch 1/10
# 9/9 [==============================] - 3s 85ms/step - loss: 0.7203 - accuracy: 0.5359 - precision_4: 0.5740 - recall_4: 0.5679 - val_loss: 0.7535 - val_accuracy: 0.5078 - val_precision_4: 0.5078 - val_recall_4: 1.0000
# Epoch 2/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.7299 - accuracy: 0.5437 - precision_4: 0.5437 - recall_4: 1.0000 - val_loss: 0.6934 - val_accuracy: 0.5078 - val_precision_4: 0.5078 - val_recall_4: 1.0000
# Epoch 3/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6834 - accuracy: 0.5437 - precision_4: 0.5437 - recall_4: 1.0000 - val_loss: 0.6959 - val_accuracy: 0.5078 - val_precision_4: 0.5078 - val_recall_4: 1.0000
# Epoch 4/10
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6753 - accuracy: 0.5359 - precision_4: 0.5432 - recall_4: 0.9214 - val_loss: 0.6963 - val_accuracy: 0.4844 - val_precision_4: 0.4954 - val_recall_4: 0.8308
# Epoch 5/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6713 - accuracy: 0.6350 - precision_4: 0.6285 - recall_4: 0.8036 - val_loss: 0.7008 - val_accuracy: 0.5000 - val_precision_4: 0.5039 - val_recall_4: 0.9846
# Epoch 6/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6460 - accuracy: 0.5981 - precision_4: 0.5813 - recall_4: 0.9321 - val_loss: 0.7431 - val_accuracy: 0.5078 - val_precision_4: 0.5078 - val_recall_4: 1.0000
# Epoch 7/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6461 - accuracy: 0.5806 - precision_4: 0.5669 - recall_4: 0.9679 - val_loss: 0.6970 - val_accuracy: 0.5078 - val_precision_4: 0.5086 - val_recall_4: 0.9077
# Epoch 8/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6144 - accuracy: 0.6485 - precision_4: 0.6165 - recall_4: 0.9357 - val_loss: 0.7285 - val_accuracy: 0.5000 - val_precision_4: 0.5039 - val_recall_4: 0.9846
# Epoch 9/10
# 9/9 [==============================] - 0s 27ms/step - loss: 0.5856 - accuracy: 0.6350 - precision_4: 0.6070 - recall_4: 0.9321 - val_loss: 0.7486 - val_accuracy: 0.5000 - val_precision_4: 0.5039 - val_recall_4: 0.9846
# Epoch 10/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5737 - accuracy: 0.6466 - precision_4: 0.6167 - recall_4: 0.9250 - val_loss: 0.7236 - val_accuracy: 0.5234 - val_precision_4: 0.5196 - val_recall_4: 0.8154
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6875 - accuracy: 0.4410 - precision_4: 0.4656 - recall_4: 0.7531
# Best Model: Model_0

# %%
from matplotlib import pyplot as plt

# %%
plt.title('model training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model training accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['accuracy'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_accuracy'], label="model_{}".format(key))
plt.legend()

# %%
print("Loss: {}, Accuracy: {}, Precision: {}, Recall: {}, F1 Score: {}".format(
    np.average(loss), np.average(accuracy), np.average(precision), np.average(recall), np.average(F1)
))
# Out:
# Loss: 0.7658403515815735, Accuracy: 0.4993788778781891, Precision: 0.5151741743087769, Recall: 0.6666666686534881, F1 Score: 0.5504553196843587

# %%
best_model.save("Transformer_FAKES")
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.embeddings.Embedding object at 0x000001B71F0E88B0>, because it is not built.
# WARNING:absl:Found untraced functions such as embedding_layer_call_and_return_conditional_losses, embedding_layer_call_fn, embedding_1_layer_call_and_return_conditional_losses, embedding_1_layer_call_fn, multi_head_self_attention_layer_call_and_return_conditional_losses while saving (showing 5 of 55). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Transformer_FAKES\assets
# INFO:tensorflow:Assets written to: Transformer_FAKES\assets
