# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import numpy as np

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11556731679394178477
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3643801600
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4282909439628561169
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
# MAX_VNUM = 20000
SEQUENCE_LENGTH = 300
EMBED_DIMENSION = 100
BATCH_SIZE = 64
K_FOLD = 5

# %%
column_names = ["lemmatized_clean_final_article", "labels"]
data = pd.read_csv("../Preprocessed_Dataset/Fakes_Preprocessed_Data.csv", encoding='utf-8', encoding_errors='ignore')[column_names]
train, test = train_test_split(data, test_size=0.2)

# %%
token = keras.preprocessing.text.Tokenizer()
token.fit_on_texts(data[column_names[0]])
vocab_size = len(token.word_index) + 2

# %%
embedding_vector = {}
f = open('../data/glove.6B.100d.txt')
for line in tqdm(f):
    word, coefs = line.split(maxsplit=1)
    coefs = np.fromstring(coefs, "f", sep=" ")
    embedding_vector[word] = coefs
embedding_matrix = np.zeros((vocab_size, EMBED_DIMENSION))
for word,i in tqdm(token.word_index.items()):
    embedding_value = embedding_vector.get(word)
    if embedding_value is not None:
        embedding_matrix[i] = embedding_value
# Out:
# 400000it [00:09, 43749.30it/s]
# 100%|██████████| 10014/10014 [00:00<00:00, 1211088.50it/s]

# %% [markdown]
# ### Model

# %%
def model_generator():
    model = keras.models.Sequential()
    model.add(layers.Embedding(input_dim=vocab_size, output_dim=EMBED_DIMENSION, 
                        embeddings_initializer=keras.initializers.Constant(embedding_matrix), 
                        input_length=SEQUENCE_LENGTH, trainable = False))
    model.add(layers.Permute((2, 1)))
    model.add(layers.Conv1D(128, 5, activation='relu', name="Conv1D"))
    model.add(layers.MaxPooling1D(pool_size=2, name="MaxPooling1D"))
    model.add(layers.LSTM(32, 
                        #   activation=None, 
                          name="LSTM"))
    model.add(layers.Dense(1, activation="sigmoid"))
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=[
        "accuracy",
        tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
    ])
    return model

# %%
train_x = token.texts_to_sequences(train[column_names[0]])
train_x = keras.preprocessing.sequence.pad_sequences(train_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
train_y = train[column_names[1]]

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = K_FOLD)
history = {}
loss, accuracy, precision, recall, F1 = np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD), np.zeros(K_FOLD)
id = 0
epochs = 10
test_x = token.texts_to_sequences(test[column_names[0]])
test_x = keras.preprocessing.sequence.pad_sequences(test_x, maxlen=SEQUENCE_LENGTH, padding='post', truncating="post")
test_y = test[column_names[1]]
best_model = None
best_f1 = 0
best_id = 0
for train_index, val_index in kf.split(train_x, train_y):
    training_x, training_y = train_x[train_index], train_y.iloc[train_index]
    validation_x, validation_y = train_x[val_index], train_y.iloc[val_index]
    model = model_generator()
    history[id] = model.fit(x=training_x, y=training_y, validation_data=(validation_x, validation_y),
                                               epochs=epochs, batch_size=BATCH_SIZE)
    loss[id], accuracy[id], precision[id], recall[id] = model.evaluate(x=test_x, y=test_y)
    F1[id] = 2 * (precision[id] * recall[id]) / (precision[id] + recall[id])
    if F1[id] > best_f1:
        best_model = model
        best_f1 = F1[id]
        best_id = id
    id += 1
print("Best Model: Model_{}".format(best_id))
# Out:
# Epoch 1/10
# 9/9 [==============================] - 9s 88ms/step - loss: 0.6970 - accuracy: 0.5136 - precision: 0.5372 - recall: 0.5846 - val_loss: 0.7132 - val_accuracy: 0.5194 - val_precision: 0.5197 - val_recall: 0.9851
# Epoch 2/10
# 9/9 [==============================] - 0s 11ms/step - loss: 0.6102 - accuracy: 0.7082 - precision: 0.6510 - recall: 0.9669 - val_loss: 0.7210 - val_accuracy: 0.4419 - val_precision: 0.4648 - val_recall: 0.4925
# Epoch 3/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.4877 - accuracy: 0.8852 - precision: 0.8930 - recall: 0.8897 - val_loss: 0.8574 - val_accuracy: 0.4496 - val_precision: 0.4804 - val_recall: 0.7313
# Epoch 4/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2822 - accuracy: 0.9144 - precision: 0.8958 - recall: 0.9485 - val_loss: 1.2124 - val_accuracy: 0.5194 - val_precision: 0.5352 - val_recall: 0.5672
# Epoch 5/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1509 - accuracy: 0.9514 - precision: 0.9768 - recall: 0.9301 - val_loss: 1.6762 - val_accuracy: 0.5039 - val_precision: 0.5161 - val_recall: 0.7164
# Epoch 6/10
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1149 - accuracy: 0.9728 - precision: 0.9574 - recall: 0.9926 - val_loss: 1.7912 - val_accuracy: 0.4729 - val_precision: 0.4762 - val_recall: 0.1493
# Epoch 7/10
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1551 - accuracy: 0.9436 - precision: 0.9880 - recall: 0.9044 - val_loss: 1.7497 - val_accuracy: 0.4729 - val_precision: 0.4951 - val_recall: 0.7612
# Epoch 8/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0737 - accuracy: 0.9844 - precision: 0.9853 - recall: 0.9853 - val_loss: 1.7283 - val_accuracy: 0.4884 - val_precision: 0.5094 - val_recall: 0.4030
# Epoch 9/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0574 - accuracy: 0.9825 - precision: 0.9888 - recall: 0.9779 - val_loss: 1.8331 - val_accuracy: 0.5039 - val_precision: 0.5231 - val_recall: 0.5075
# Epoch 10/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0489 - accuracy: 0.9864 - precision: 0.9853 - recall: 0.9890 - val_loss: 1.9354 - val_accuracy: 0.4884 - val_precision: 0.5067 - val_recall: 0.5672
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1344 - accuracy: 0.4907 - precision: 0.5287 - recall: 0.5287
# Epoch 1/10
# 9/9 [==============================] - 2s 81ms/step - loss: 0.6951 - accuracy: 0.5058 - precision_1: 0.5236 - recall_1: 0.4205 - val_loss: 0.6818 - val_accuracy: 0.5659 - val_precision_1: 0.5748 - val_recall_1: 0.9733
# Epoch 2/10
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6298 - accuracy: 0.5856 - precision_1: 0.5535 - recall_1: 1.0000 - val_loss: 0.7058 - val_accuracy: 0.5116 - val_precision_1: 0.5652 - val_recall_1: 0.6933
# Epoch 3/10
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5060 - accuracy: 0.8307 - precision_1: 0.7723 - recall_1: 0.9508 - val_loss: 0.7742 - val_accuracy: 0.5039 - val_precision_1: 0.5618 - val_recall_1: 0.6667
# Epoch 4/10
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2785 - accuracy: 0.9280 - precision_1: 0.9068 - recall_1: 0.9583 - val_loss: 1.2209 - val_accuracy: 0.5349 - val_precision_1: 0.5641 - val_recall_1: 0.8800
# Epoch 5/10
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1476 - accuracy: 0.9591 - precision_1: 0.9483 - recall_1: 0.9735 - val_loss: 1.7082 - val_accuracy: 0.4496 - val_precision_1: 0.5500 - val_recall_1: 0.2933
# Epoch 6/10
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0918 - accuracy: 0.9767 - precision_1: 0.9773 - recall_1: 0.9773 - val_loss: 1.9948 - val_accuracy: 0.4186 - val_precision_1: 0.5000 - val_recall_1: 0.2400
# Epoch 7/10
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1065 - accuracy: 0.9689 - precision_1: 0.9806 - recall_1: 0.9583 - val_loss: 1.5006 - val_accuracy: 0.4884 - val_precision_1: 0.5652 - val_recall_1: 0.5200
# Epoch 8/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0741 - accuracy: 0.9805 - precision_1: 0.9885 - recall_1: 0.9735 - val_loss: 1.8170 - val_accuracy: 0.5039 - val_precision_1: 0.5696 - val_recall_1: 0.6000
# Epoch 9/10
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0596 - accuracy: 0.9825 - precision_1: 0.9885 - recall_1: 0.9773 - val_loss: 2.1481 - val_accuracy: 0.4341 - val_precision_1: 0.5200 - val_recall_1: 0.3467
# Epoch 10/10
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0579 - accuracy: 0.9825 - precision_1: 0.9923 - recall_1: 0.9735 - val_loss: 2.0077 - val_accuracy: 0.5039 - val_precision_1: 0.5647 - val_recall_1: 0.6400
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1577 - accuracy: 0.4658 - precision_1: 0.5048 - recall_1: 0.6092
# Epoch 1/10
# 9/9 [==============================] - 3s 86ms/step - loss: 0.7051 - accuracy: 0.4728 - precision_2: 0.5060 - recall_2: 0.3077 - val_loss: 0.6971 - val_accuracy: 0.5116 - val_precision_2: 0.5116 - val_recall_2: 1.0000
# Epoch 2/10
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6449 - accuracy: 0.5428 - precision_2: 0.5374 - recall_2: 1.0000 - val_loss: 0.7061 - val_accuracy: 0.5116 - val_precision_2: 0.5116 - val_recall_2: 1.0000
# Epoch 3/10
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5588 - accuracy: 0.7490 - precision_2: 0.6846 - recall_2: 0.9780 - val_loss: 0.7157 - val_accuracy: 0.4884 - val_precision_2: 0.5000 - val_recall_2: 0.7727
# Epoch 4/10
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4035 - accuracy: 0.8541 - precision_2: 0.7946 - recall_2: 0.9780 - val_loss: 0.8676 - val_accuracy: 0.4884 - val_precision_2: 0.5000 - val_recall_2: 0.5000
# Epoch 5/10
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2030 - accuracy: 0.9514 - precision_2: 0.9429 - recall_2: 0.9670 - val_loss: 1.3799 - val_accuracy: 0.5039 - val_precision_2: 0.5333 - val_recall_2: 0.2424
# Epoch 6/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1535 - accuracy: 0.9533 - precision_2: 0.9594 - recall_2: 0.9524 - val_loss: 1.7892 - val_accuracy: 0.4419 - val_precision_2: 0.4400 - val_recall_2: 0.3333
# Epoch 7/10
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1660 - accuracy: 0.9475 - precision_2: 0.9881 - recall_2: 0.9121 - val_loss: 1.5142 - val_accuracy: 0.4729 - val_precision_2: 0.4886 - val_recall_2: 0.6515
# Epoch 8/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1085 - accuracy: 0.9708 - precision_2: 0.9743 - recall_2: 0.9707 - val_loss: 1.5117 - val_accuracy: 0.4186 - val_precision_2: 0.4328 - val_recall_2: 0.4394
# Epoch 9/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0889 - accuracy: 0.9747 - precision_2: 0.9924 - recall_2: 0.9597 - val_loss: 1.7484 - val_accuracy: 0.4729 - val_precision_2: 0.4878 - val_recall_2: 0.6061
# Epoch 10/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0878 - accuracy: 0.9708 - precision_2: 0.9640 - recall_2: 0.9817 - val_loss: 1.8494 - val_accuracy: 0.4496 - val_precision_2: 0.4528 - val_recall_2: 0.3636
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9165 - accuracy: 0.4410 - precision_2: 0.4795 - recall_2: 0.4023
# Epoch 1/10
# 9/9 [==============================] - 3s 91ms/step - loss: 0.6982 - accuracy: 0.5301 - precision_3: 0.5383 - recall_3: 0.8212 - val_loss: 0.6973 - val_accuracy: 0.5156 - val_precision_3: 0.6364 - val_recall_3: 0.1077
# Epoch 2/10
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6273 - accuracy: 0.6757 - precision_3: 0.9652 - recall_3: 0.4051 - val_loss: 0.6946 - val_accuracy: 0.5234 - val_precision_3: 0.5250 - val_recall_3: 0.6462
# Epoch 3/10
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5256 - accuracy: 0.8214 - precision_3: 0.7571 - recall_3: 0.9781 - val_loss: 0.7295 - val_accuracy: 0.5000 - val_precision_3: 0.5106 - val_recall_3: 0.3692
# Epoch 4/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3582 - accuracy: 0.9087 - precision_3: 0.9283 - recall_3: 0.8978 - val_loss: 0.9299 - val_accuracy: 0.4844 - val_precision_3: 0.4932 - val_recall_3: 0.5538
# Epoch 5/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1820 - accuracy: 0.9359 - precision_3: 0.9689 - recall_3: 0.9088 - val_loss: 1.5066 - val_accuracy: 0.4766 - val_precision_3: 0.4906 - val_recall_3: 0.8000
# Epoch 6/10
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1490 - accuracy: 0.9456 - precision_3: 0.9843 - recall_3: 0.9124 - val_loss: 1.6759 - val_accuracy: 0.4297 - val_precision_3: 0.4231 - val_recall_3: 0.3385
# Epoch 7/10
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1141 - accuracy: 0.9631 - precision_3: 0.9705 - recall_3: 0.9599 - val_loss: 1.6519 - val_accuracy: 0.4531 - val_precision_3: 0.4667 - val_recall_3: 0.5385
# Epoch 8/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0946 - accuracy: 0.9786 - precision_3: 0.9817 - recall_3: 0.9781 - val_loss: 1.8256 - val_accuracy: 0.3984 - val_precision_3: 0.3889 - val_recall_3: 0.3231
# Epoch 9/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0810 - accuracy: 0.9748 - precision_3: 0.9851 - recall_3: 0.9672 - val_loss: 1.8108 - val_accuracy: 0.4375 - val_precision_3: 0.4103 - val_recall_3: 0.2462
# Epoch 10/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0661 - accuracy: 0.9825 - precision_3: 0.9926 - recall_3: 0.9745 - val_loss: 1.9988 - val_accuracy: 0.4453 - val_precision_3: 0.4625 - val_recall_3: 0.5692
# 6/6 [==============================] - 1s 5ms/step - loss: 2.0211 - accuracy: 0.4783 - precision_3: 0.5146 - recall_3: 0.6092
# Epoch 1/10
# 9/9 [==============================] - 3s 89ms/step - loss: 0.7046 - accuracy: 0.4505 - precision_4: 0.4855 - recall_4: 0.6117 - val_loss: 0.7182 - val_accuracy: 0.5156 - val_precision_4: 0.5156 - val_recall_4: 1.0000
# Epoch 2/10
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6248 - accuracy: 0.6136 - precision_4: 0.5784 - recall_4: 1.0000 - val_loss: 0.7092 - val_accuracy: 0.4141 - val_precision_4: 0.4458 - val_recall_4: 0.5606
# Epoch 3/10
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5526 - accuracy: 0.8757 - precision_4: 0.9604 - recall_4: 0.7985 - val_loss: 0.7408 - val_accuracy: 0.4141 - val_precision_4: 0.4182 - val_recall_4: 0.3485
# Epoch 4/10
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3914 - accuracy: 0.9087 - precision_4: 0.9124 - recall_4: 0.9158 - val_loss: 0.9668 - val_accuracy: 0.4453 - val_precision_4: 0.4324 - val_recall_4: 0.2424
# Epoch 5/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2096 - accuracy: 0.9398 - precision_4: 0.9764 - recall_4: 0.9084 - val_loss: 1.4099 - val_accuracy: 0.4453 - val_precision_4: 0.4731 - val_recall_4: 0.6667
# Epoch 6/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0841 - accuracy: 0.9864 - precision_4: 0.9890 - recall_4: 0.9853 - val_loss: 2.1425 - val_accuracy: 0.3984 - val_precision_4: 0.4098 - val_recall_4: 0.3788
# Epoch 7/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0695 - accuracy: 0.9845 - precision_4: 0.9818 - recall_4: 0.9890 - val_loss: 2.1176 - val_accuracy: 0.4766 - val_precision_4: 0.4737 - val_recall_4: 0.1364
# Epoch 8/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0957 - accuracy: 0.9767 - precision_4: 0.9925 - recall_4: 0.9634 - val_loss: 2.0063 - val_accuracy: 0.4922 - val_precision_4: 0.5067 - val_recall_4: 0.5758
# Epoch 9/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0494 - accuracy: 0.9903 - precision_4: 0.9963 - recall_4: 0.9853 - val_loss: 1.8885 - val_accuracy: 0.5234 - val_precision_4: 0.5532 - val_recall_4: 0.3939
# Epoch 10/10
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0505 - accuracy: 0.9883 - precision_4: 0.9963 - recall_4: 0.9817 - val_loss: 2.1774 - val_accuracy: 0.4688 - val_precision_4: 0.4884 - val_recall_4: 0.6364
# 6/6 [==============================] - 1s 5ms/step - loss: 2.2044 - accuracy: 0.4596 - precision_4: 0.5000 - recall_4: 0.6897
# Best Model: Model_4

# %%
from matplotlib import pyplot as plt

# %%
plt.title('model training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model training accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['accuracy'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_loss'], label="model_{}".format(key))
plt.legend()

# %%
plt.title('model validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
for key in history.keys():
    plt.plot(history[key].history['val_accuracy'], label="model_{}".format(key))
plt.legend()

# %%
print("Loss: {}, Accuracy: {}, Precision: {}, Recall: {}, F1 Score: {}".format(
    np.average(loss), np.average(accuracy), np.average(precision), np.average(recall), np.average(F1)
))
# Out:
# Loss: 2.086823558807373, Accuracy: 0.46708074808120725, Precision: 0.5055025398731232, Recall: 0.5678160965442658, F1 Score: 0.5311847712968067

# %%
best_model.save("Hybrid_FAKES")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Hybrid_FAKES\assets
# INFO:tensorflow:Assets written to: Hybrid_FAKES\assets
