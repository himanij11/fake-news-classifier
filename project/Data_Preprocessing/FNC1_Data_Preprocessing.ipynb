# %%
import os
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
current_directory = os.path.abspath(os.getcwd())
print(current_directory)
os.chdir(f"{current_directory}/fnc1_Dataset")
# Out:
# C:\Users\cobra\project\project\Data_Preprocessing

# %%
os.getcwd()
# Out:
# 'C:\\Users\\cobra\\project\\project\\Data_Preprocessing\\fnc1_Dataset'

# %%
fnc1_csv_path = os.path.join(os.getcwd(), 'FNC1_Combined_Data.csv')
print(fnc1_csv_path)
# Out:
# C:\Users\cobra\project\project\Data_Preprocessing\fnc1_Dataset\FNC1_Combined_Data.csv

# %%
df = pd.read_csv(fnc1_csv_path, encoding='utf-8', encoding_errors='ignore')
df.head()
# Out:
#    Body ID                                        articleBody  \
# 0        0  A small meteorite crashed into a wooded area i...
# 1        8  There is so much fake stuff on the Internet in...
# 2        9  (CNN) -- A meteorite crashed down in Managua, ...
# 3        9  (CNN) -- A meteorite crashed down in Managua, ...
# 4       13  A SOLDIER has been shot at Canada’s National W...
#
#                                             Headline Stance  labels
# 0  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 1  What was fake on the Internet this week: Obama...  agree       1
# 2  Meteorite makes big crater in Nicaragua, gover...  agree       1
# 3  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 4  A soldier has been shot at Canada’s war memori...  agree       1

# %%
# df[df['Stance'] == 'agree'].shape
# df[df['Stance'] == 'disagree'].shape

# %%
# sns.countplot(df['Stance'])

# %%
# df = df[['articleBody', 'labels']]
# df.head()

# %%
df['final_article'] = df['Headline'] +" "+ df['articleBody']
df.head()
# Out:
#    Body ID                                        articleBody  \
# 0        0  A small meteorite crashed into a wooded area i...
# 1        8  There is so much fake stuff on the Internet in...
# 2        9  (CNN) -- A meteorite crashed down in Managua, ...
# 3        9  (CNN) -- A meteorite crashed down in Managua, ...
# 4       13  A SOLDIER has been shot at Canada’s National W...
#
#                                             Headline Stance  labels  \
# 0  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 1  What was fake on the Internet this week: Obama...  agree       1
# 2  Meteorite makes big crater in Nicaragua, gover...  agree       1
# 3  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 4  A soldier has been shot at Canada’s war memori...  agree       1
#
#                                        final_article
# 0  Small Meteorite Strikes in Nicaragua's Capital...
# 1  What was fake on the Internet this week: Obama...
# 2  Meteorite makes big crater in Nicaragua, gover...
# 3  Small Meteorite Strikes in Nicaragua's Capital...
# 4  A soldier has been shot at Canada’s war memori...

# %%
df[df.duplicated()]
# Out:
#       Body ID                                        articleBody  \
# 244       474  Eran Cicurel, an editor at Voice of Israel, ha...
# 518       756  Gill Rosenberg, the Canadian Israeli volunteer...
# 705       899  A nun who complained of stomach pains shocked ...
# 906      1026  McDonald’s has just announced that it will be ...
# 1175     1213  Nicaraguan officials say a meteorite gouged ou...
# 1324     1295  A Canadian-Israeli woman who was feared kidnap...
# 1391     1318  (Reuters) - Even in India, where government jo...
# 1470     1355  LONDON (Reuters) - No suspected cases of Ebola...
# 1479     1358  It's not every night that a pizza delivery dri...
# 1592     1412  A cloistered nun has stunned her mother superi...
# 1935     1573  Astronomers, including experts at NASA, have q...
# 2007     1594  (Update: The story has been updated to reflect...
# 2202     1731  No one was hurt\r\n\r\nA small meteorite struc...
# 2247     1742  Barack and Michelle Obama are in Riyadh today ...
# 2311     1777  An article saying McDonald’s is removing the B...
# 2316     1778  The New York Post decided that it was a good i...
# 2599     1862  BREAKING: Gill Rosenberg (31) from Tel Aviv fo...
# 2747     1913  A blast near the Nicaraguan capital city of Ma...
# 2840     1951  An executive engineer at the Central Public Wo...
# 2944     1975  Video clips circulated online Tuesday that pur...
# 2949     1976  Sources in the Kurdish underground in Syria de...
# 3091     2037  The Canadian woman who was reportedly kidnappe...
# 3178     2060  The two biggest news stories of 2014 collided ...
# 3284     2104  KANSAS CITY, MO (KCTV) -\r\nA man rushed to a ...
# 3307     2122  Now that's a special delivery!\r\nA group of r...
# 3323     2127  KANSAS CITY, Mo. - Kansas City health official...
# 3347     2134  An official of the Central Public Works Depart...
# 3373     2138  The Islamic State (Isis) operating in Iraq doe...
# 3396     2142  Gillian Rosenberg, the Canadian-Israeli woman ...
# 3456     2167  (Reuters) - A prominent Saudi Arabian cleric h...
# 3500     2177  On Monday morning, a report surfaced claiming ...
# 3508     2178  Comcast has lately found itself issuing public...
# 3512     2180  No suspected cases of Ebola have been found in...
# 3691     2248  SEVEN girls, aged 13 to 15, have fallen pregna...
# 4194     2441  An Indian public official has been sacked for ...
# 4261     2453  A short video clip has been circulating online...
# 4270     2456  Manama: Saudis in the northern areas drew on t...
# 4321     2475  We reported on Monday that a meteor, thought p...
# 4348     2492  SAN SEVERINO - Go to the hospital accusing a t...
# 4381     2501  In response to Ebola Scare in Kansas City :\r\...
# 4402     2504  Seven girls aged between 13 and 14 have fallen...
# 4412     2508  28 girls, aged 13 and 14, from a small town we...
# 4517     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
#
#                                                Headline    Stance  labels  \
# 244   YPG Confirms: Gill Rosenberg Not Captured in K...     agree       1
# 518   YPG Confirms: Gill Rosenberg Not Captured in K...     agree       1
# 705   Nun gives birth to surprise baby after complai...     agree       1
# 906   McDonald’s Removing Big Mac, Apple Pies And El...     agree       1
# 1175  Meteorite leaves crater in Nicaraguan capital ...  disagree       0
# 1324  YPG Confirms: Gill Rosenberg Not Captured in K...     agree       1
# 1391  Government fires employee who skipped work for...     agree       1
# 1470  WHO says reports of suspected Ebola cases in I...     agree       1
# 1479  Ann Arbor pizza delivery driver surprised with...     agree       1
# 1592  Nun gives birth to surprise baby after complai...     agree       1
# 1935  Meteorite leaves crater in Nicaraguan capital ...  disagree       0
# 2007  Meteorite leaves crater in Nicaraguan capital ...  disagree       0
# 2202  Meteorite leaves crater in Nicaraguan capital ...     agree       1
# 2247  Michelle Obama’s face blurred by Saudi state t...  disagree       0
# 2311  McDonald’s Removing Big Mac, Apple Pies And El...  disagree       0
# 2316  WHO says reports of suspected Ebola cases in I...     agree       1
# 2599  YPG Confirms: Gill Rosenberg Not Captured in K...  disagree       0
# 2747  Meteorite leaves crater in Nicaraguan capital ...     agree       1
# 2840  Government fires employee who skipped work for...     agree       1
# 2944  Michelle Obama’s face blurred by Saudi state t...  disagree       0
# 2949  YPG Confirms: Gill Rosenberg Not Captured in K...     agree       1
# 3091  YPG Confirms: Gill Rosenberg Not Captured in K...     agree       1
# 3178  WHO says reports of suspected Ebola cases in I...     agree       1
# 3284  Hospital: Man not being treated for Ebola in K...     agree       1
# 3307  Ann Arbor pizza delivery driver surprised with...     agree       1
# 3323  Hospital: Man not being treated for Ebola in K...     agree       1
# 3347  Government fires employee who skipped work for...     agree       1
# 3373  WHO says reports of suspected Ebola cases in I...     agree       1
# 3396  YPG Confirms: Gill Rosenberg Not Captured in K...     agree       1
# 3456      Saudi cleric condemns snowmen as anti-Islamic     agree       1
# 3500  Comcast Is Threatening To Cut Off Customers Wh...  disagree       0
# 3508  Comcast Is Threatening To Cut Off Customers Wh...  disagree       0
# 3512  WHO says reports of suspected Ebola cases in I...     agree       1
# 3691  Seven girls fall pregnant after five day schoo...     agree       1
# 4194  Government fires employee who skipped work for...     agree       1
# 4261  Michelle Obama’s face blurred by Saudi state t...  disagree       0
# 4270      Saudi cleric condemns snowmen as anti-Islamic     agree       1
# 4321  Meteorite leaves crater in Nicaraguan capital ...  disagree       0
# 4348  Nun gives birth to surprise baby after complai...     agree       1
# 4381  Hospital: Man not being treated for Ebola in K...     agree       1
# 4402  Seven girls fall pregnant after five day schoo...     agree       1
# 4412  Seven girls fall pregnant after five day schoo...     agree       1
# 4517  Ann Arbor pizza delivery driver surprised with...     agree       1
#
#                                           final_article
# 244   YPG Confirms: Gill Rosenberg Not Captured in K...
# 518   YPG Confirms: Gill Rosenberg Not Captured in K...
# 705   Nun gives birth to surprise baby after complai...
# 906   McDonald’s Removing Big Mac, Apple Pies And El...
# 1175  Meteorite leaves crater in Nicaraguan capital ...
# 1324  YPG Confirms: Gill Rosenberg Not Captured in K...
# 1391  Government fires employee who skipped work for...
# 1470  WHO says reports of suspected Ebola cases in I...
# 1479  Ann Arbor pizza delivery driver surprised with...
# 1592  Nun gives birth to surprise baby after complai...
# 1935  Meteorite leaves crater in Nicaraguan capital ...
# 2007  Meteorite leaves crater in Nicaraguan capital ...
# 2202  Meteorite leaves crater in Nicaraguan capital ...
# 2247  Michelle Obama’s face blurred by Saudi state t...
# 2311  McDonald’s Removing Big Mac, Apple Pies And El...
# 2316  WHO says reports of suspected Ebola cases in I...
# 2599  YPG Confirms: Gill Rosenberg Not Captured in K...
# 2747  Meteorite leaves crater in Nicaraguan capital ...
# 2840  Government fires employee who skipped work for...
# 2944  Michelle Obama’s face blurred by Saudi state t...
# 2949  YPG Confirms: Gill Rosenberg Not Captured in K...
# 3091  YPG Confirms: Gill Rosenberg Not Captured in K...
# 3178  WHO says reports of suspected Ebola cases in I...
# 3284  Hospital: Man not being treated for Ebola in K...
# 3307  Ann Arbor pizza delivery driver surprised with...
# 3323  Hospital: Man not being treated for Ebola in K...
# 3347  Government fires employee who skipped work for...
# 3373  WHO says reports of suspected Ebola cases in I...
# 3396  YPG Confirms: Gill Rosenberg Not Captured in K...
# 3456  Saudi cleric condemns snowmen as anti-Islamic ...
# 3500  Comcast Is Threatening To Cut Off Customers Wh...
# 3508  Comcast Is Threatening To Cut Off Customers Wh...
# 3512  WHO says reports of suspected Ebola cases in I...
# 3691  Seven girls fall pregnant after five day schoo...
# 4194  Government fires employee who skipped work for...
# 4261  Michelle Obama’s face blurred by Saudi state t...
# 4270  Saudi cleric condemns snowmen as anti-Islamic ...
# 4321  Meteorite leaves crater in Nicaraguan capital ...
# 4348  Nun gives birth to surprise baby after complai...
# 4381  Hospital: Man not being treated for Ebola in K...
# 4402  Seven girls fall pregnant after five day schoo...
# 4412  Seven girls fall pregnant after five day schoo...
# 4517  Ann Arbor pizza delivery driver surprised with...

# %%
df['final_article'].str.len()
# Out:
# 0       1982
# 1       8136
# 2       3095
# 3       3101
# 4        492
#         ...
# 4513     619
# 4514     584
# 4515     598
# 4516     607
# 4517     607
# Name: final_article, Length: 4518, dtype: int64

# %%
df['final_article'] = df['final_article'].str.lower()

# %%
df
# Out:
#       Body ID                                        articleBody  \
# 0           0  A small meteorite crashed into a wooded area i...
# 1           8  There is so much fake stuff on the Internet in...
# 2           9  (CNN) -- A meteorite crashed down in Managua, ...
# 3           9  (CNN) -- A meteorite crashed down in Managua, ...
# 4          13  A SOLDIER has been shot at Canada’s National W...
# ...       ...                                                ...
# 4513     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
# 4514     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
# 4515     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
# 4516     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
# 4517     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
#
#                                                Headline Stance  labels  \
# 0     Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 1     What was fake on the Internet this week: Obama...  agree       1
# 2     Meteorite makes big crater in Nicaragua, gover...  agree       1
# 3     Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 4     A soldier has been shot at Canada’s war memori...  agree       1
# ...                                                 ...    ...     ...
# 4513  Pizza delivery man gets tipped more than $2,00...  agree       1
# 4514                 Pizza delivery man gets $2,000 tip  agree       1
# 4515   Luckiest Pizza Delivery Guy Ever Gets $2,000 Tip  agree       1
# 4516  Ann Arbor pizza delivery driver surprised with...  agree       1
# 4517  Ann Arbor pizza delivery driver surprised with...  agree       1
#
#                                           final_article
# 0     small meteorite strikes in nicaragua's capital...
# 1     what was fake on the internet this week: obama...
# 2     meteorite makes big crater in nicaragua, gover...
# 3     small meteorite strikes in nicaragua's capital...
# 4     a soldier has been shot at canada’s war memori...
# ...                                                 ...
# 4513  pizza delivery man gets tipped more than $2,00...
# 4514  pizza delivery man gets $2,000 tip ann arbor, ...
# 4515  luckiest pizza delivery guy ever gets $2,000 t...
# 4516  ann arbor pizza delivery driver surprised with...
# 4517  ann arbor pizza delivery driver surprised with...
#
# [4518 rows x 6 columns]

# %%
df.head()
# Out:
#    Body ID                                        articleBody  \
# 0        0  A small meteorite crashed into a wooded area i...
# 1        8  There is so much fake stuff on the Internet in...
# 2        9  (CNN) -- A meteorite crashed down in Managua, ...
# 3        9  (CNN) -- A meteorite crashed down in Managua, ...
# 4       13  A SOLDIER has been shot at Canada’s National W...
#
#                                             Headline Stance  labels  \
# 0  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 1  What was fake on the Internet this week: Obama...  agree       1
# 2  Meteorite makes big crater in Nicaragua, gover...  agree       1
# 3  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 4  A soldier has been shot at Canada’s war memori...  agree       1
#
#                                        final_article
# 0  small meteorite strikes in nicaragua's capital...
# 1  what was fake on the internet this week: obama...
# 2  meteorite makes big crater in nicaragua, gover...
# 3  small meteorite strikes in nicaragua's capital...
# 4  a soldier has been shot at canada’s war memori...

# %%
df['labels'].value_counts()
# Out:
# 1    3678
# 0     840
# Name: labels, dtype: int64

# %%
df.isna().sum()
# Out:
# Body ID          0
# articleBody      0
# Headline         0
# Stance           0
# labels           0
# final_article    0
# dtype: int64

# %%
# Getting count of rows containing urls
url_regex = r'[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)'
# url_regex = r'https?://\S+|www\.\S+'
# url_regex = r'(https?:\/\/(?:www\.)?[-a-zA-Z0-9@:%._+~#=]{1,256}]\.[a-zA-Z0-9()]{1,6}[-a-zA-Z0-9()@:%_+.~#?&/=]*)'
url_count = df.final_article.str.contains(url_regex, regex=True)
# url_count[url_count]
url_count[url_count].shape
# Out:
# C:\Users\cobra\AppData\Local\Temp\ipykernel_7176\1049594794.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   url_count = df.final_article.str.contains(url_regex, regex=True)
# (1816,)

# %%
url_count
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 4513    False
# 4514    False
# 4515    False
# 4516    False
# 4517    False
# Name: final_article, Length: 4518, dtype: bool

# %%
def remove_url(url_text):
    # url = re.compile(r'https?://\S+|www\.\S+')
    url = re.compile(r'[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)')
    # re.sub(r'http\S+', ' ', url_text)
    return url.sub(r'', url_text)

df['clean_final_article'] = df['final_article'].apply(remove_url)

# %%
df
# Out:
#       Body ID                                        articleBody  \
# 0           0  A small meteorite crashed into a wooded area i...
# 1           8  There is so much fake stuff on the Internet in...
# 2           9  (CNN) -- A meteorite crashed down in Managua, ...
# 3           9  (CNN) -- A meteorite crashed down in Managua, ...
# 4          13  A SOLDIER has been shot at Canada’s National W...
# ...       ...                                                ...
# 4513     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
# 4514     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
# 4515     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
# 4516     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
# 4517     2532  ANN ARBOR, Mich. – A pizza delivery man in Mic...
#
#                                                Headline Stance  labels  \
# 0     Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 1     What was fake on the Internet this week: Obama...  agree       1
# 2     Meteorite makes big crater in Nicaragua, gover...  agree       1
# 3     Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 4     A soldier has been shot at Canada’s war memori...  agree       1
# ...                                                 ...    ...     ...
# 4513  Pizza delivery man gets tipped more than $2,00...  agree       1
# 4514                 Pizza delivery man gets $2,000 tip  agree       1
# 4515   Luckiest Pizza Delivery Guy Ever Gets $2,000 Tip  agree       1
# 4516  Ann Arbor pizza delivery driver surprised with...  agree       1
# 4517  Ann Arbor pizza delivery driver surprised with...  agree       1
#
#                                           final_article  \
# 0     small meteorite strikes in nicaragua's capital...
# 1     what was fake on the internet this week: obama...
# 2     meteorite makes big crater in nicaragua, gover...
# 3     small meteorite strikes in nicaragua's capital...
# 4     a soldier has been shot at canada’s war memori...
# ...                                                 ...
# 4513  pizza delivery man gets tipped more than $2,00...
# 4514  pizza delivery man gets $2,000 tip ann arbor, ...
# 4515  luckiest pizza delivery guy ever gets $2,000 t...
# 4516  ann arbor pizza delivery driver surprised with...
# 4517  ann arbor pizza delivery driver surprised with...
#
#                                     clean_final_article
# 0     small meteorite strikes in nicaragua's capital...
# 1     what was fake on the internet this week: obama...
# 2     meteorite makes big crater in nicaragua, gover...
# 3     small meteorite strikes in nicaragua's capital...
# 4     a soldier has been shot at canada’s war memori...
# ...                                                 ...
# 4513  pizza delivery man gets tipped more than $2,00...
# 4514  pizza delivery man gets $2,000 tip ann arbor, ...
# 4515  luckiest pizza delivery guy ever gets $2,000 t...
# 4516  ann arbor pizza delivery driver surprised with...
# 4517  ann arbor pizza delivery driver surprised with...
#
# [4518 rows x 7 columns]

# %%
# Checking again if the article contains url or not
n_url_count = df.clean_final_article.str.contains(url_regex, regex=True)
n_url_count
# Out:
# C:\Users\cobra\AppData\Local\Temp\ipykernel_7176\746054768.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   n_url_count = df.clean_final_article.str.contains(url_regex, regex=True)
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4513    False
# 4514    False
# 4515    False
# 4516    False
# 4517    False
# Name: clean_final_article, Length: 4518, dtype: bool

# %%
# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('omw-1.4')
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Performing tokenization
df['tokenize_final_article'] = df['clean_final_article'].apply(word_tokenize)
df.head()
# Out:
#    Body ID                                        articleBody  \
# 0        0  A small meteorite crashed into a wooded area i...
# 1        8  There is so much fake stuff on the Internet in...
# 2        9  (CNN) -- A meteorite crashed down in Managua, ...
# 3        9  (CNN) -- A meteorite crashed down in Managua, ...
# 4       13  A SOLDIER has been shot at Canada’s National W...
#
#                                             Headline Stance  labels  \
# 0  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 1  What was fake on the Internet this week: Obama...  agree       1
# 2  Meteorite makes big crater in Nicaragua, gover...  agree       1
# 3  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 4  A soldier has been shot at Canada’s war memori...  agree       1
#
#                                        final_article  \
# 0  small meteorite strikes in nicaragua's capital...
# 1  what was fake on the internet this week: obama...
# 2  meteorite makes big crater in nicaragua, gover...
# 3  small meteorite strikes in nicaragua's capital...
# 4  a soldier has been shot at canada’s war memori...
#
#                                  clean_final_article  \
# 0  small meteorite strikes in nicaragua's capital...
# 1  what was fake on the internet this week: obama...
# 2  meteorite makes big crater in nicaragua, gover...
# 3  small meteorite strikes in nicaragua's capital...
# 4  a soldier has been shot at canada’s war memori...
#
#                               tokenize_final_article
# 0  [small, meteorite, strikes, in, nicaragua, 's,...
# 1  [what, was, fake, on, the, internet, this, wee...
# 2  [meteorite, makes, big, crater, in, nicaragua,...
# 3  [small, meteorite, strikes, in, nicaragua, 's,...
# 4  [a, soldier, has, been, shot, at, canada, ’, s...

# %%
# Removing stopwords
stopwords = set(stopwords.words('english'))
df['stopwords_clean_final_article'] = df['tokenize_final_article'].apply(lambda x:[word for word in x if word not in stopwords])
df.head()
# Out:
#    Body ID                                        articleBody  \
# 0        0  A small meteorite crashed into a wooded area i...
# 1        8  There is so much fake stuff on the Internet in...
# 2        9  (CNN) -- A meteorite crashed down in Managua, ...
# 3        9  (CNN) -- A meteorite crashed down in Managua, ...
# 4       13  A SOLDIER has been shot at Canada’s National W...
#
#                                             Headline Stance  labels  \
# 0  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 1  What was fake on the Internet this week: Obama...  agree       1
# 2  Meteorite makes big crater in Nicaragua, gover...  agree       1
# 3  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 4  A soldier has been shot at Canada’s war memori...  agree       1
#
#                                        final_article  \
# 0  small meteorite strikes in nicaragua's capital...
# 1  what was fake on the internet this week: obama...
# 2  meteorite makes big crater in nicaragua, gover...
# 3  small meteorite strikes in nicaragua's capital...
# 4  a soldier has been shot at canada’s war memori...
#
#                                  clean_final_article  \
# 0  small meteorite strikes in nicaragua's capital...
# 1  what was fake on the internet this week: obama...
# 2  meteorite makes big crater in nicaragua, gover...
# 3  small meteorite strikes in nicaragua's capital...
# 4  a soldier has been shot at canada’s war memori...
#
#                               tokenize_final_article  \
# 0  [small, meteorite, strikes, in, nicaragua, 's,...
# 1  [what, was, fake, on, the, internet, this, wee...
# 2  [meteorite, makes, big, crater, in, nicaragua,...
# 3  [small, meteorite, strikes, in, nicaragua, 's,...
# 4  [a, soldier, has, been, shot, at, canada, ’, s...
#
#                        stopwords_clean_final_article
# 0  [small, meteorite, strikes, nicaragua, 's, cap...
# 1  [fake, internet, week, :, obama, ’, peace, pri...
# 2  [meteorite, makes, big, crater, nicaragua, ,, ...
# 3  [small, meteorite, strikes, nicaragua, 's, cap...
# 4  [soldier, shot, canada, ’, war, memorial, step...

# %%
# Performing lemmatization
lemma = WordNetLemmatizer()

def lemmatization(words):
    return [lemma.lemmatize(word) for word in words]

df['lemmatized_clean_final_article'] = df['stopwords_clean_final_article'].apply(lemmatization)

df.head()
# Out:
#    Body ID                                        articleBody  \
# 0        0  A small meteorite crashed into a wooded area i...
# 1        8  There is so much fake stuff on the Internet in...
# 2        9  (CNN) -- A meteorite crashed down in Managua, ...
# 3        9  (CNN) -- A meteorite crashed down in Managua, ...
# 4       13  A SOLDIER has been shot at Canada’s National W...
#
#                                             Headline Stance  labels  \
# 0  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 1  What was fake on the Internet this week: Obama...  agree       1
# 2  Meteorite makes big crater in Nicaragua, gover...  agree       1
# 3  Small Meteorite Strikes in Nicaragua's Capital...  agree       1
# 4  A soldier has been shot at Canada’s war memori...  agree       1
#
#                                        final_article  \
# 0  small meteorite strikes in nicaragua's capital...
# 1  what was fake on the internet this week: obama...
# 2  meteorite makes big crater in nicaragua, gover...
# 3  small meteorite strikes in nicaragua's capital...
# 4  a soldier has been shot at canada’s war memori...
#
#                                  clean_final_article  \
# 0  small meteorite strikes in nicaragua's capital...
# 1  what was fake on the internet this week: obama...
# 2  meteorite makes big crater in nicaragua, gover...
# 3  small meteorite strikes in nicaragua's capital...
# 4  a soldier has been shot at canada’s war memori...
#
#                               tokenize_final_article  \
# 0  [small, meteorite, strikes, in, nicaragua, 's,...
# 1  [what, was, fake, on, the, internet, this, wee...
# 2  [meteorite, makes, big, crater, in, nicaragua,...
# 3  [small, meteorite, strikes, in, nicaragua, 's,...
# 4  [a, soldier, has, been, shot, at, canada, ’, s...
#
#                        stopwords_clean_final_article  \
# 0  [small, meteorite, strikes, nicaragua, 's, cap...
# 1  [fake, internet, week, :, obama, ’, peace, pri...
# 2  [meteorite, makes, big, crater, nicaragua, ,, ...
# 3  [small, meteorite, strikes, nicaragua, 's, cap...
# 4  [soldier, shot, canada, ’, war, memorial, step...
#
#                       lemmatized_clean_final_article
# 0  [small, meteorite, strike, nicaragua, 's, capi...
# 1  [fake, internet, week, :, obama, ’, peace, pri...
# 2  [meteorite, make, big, crater, nicaragua, ,, g...
# 3  [small, meteorite, strike, nicaragua, 's, capi...
# 4  [soldier, shot, canada, ’, war, memorial, step...

# %%
# Convert the list of tokens into back to the string
# df['string_article_content'] = df['lemma_clean_article_content'].apply(' '.join)
# df

# %%
df.drop(columns=['Body ID', 'Stance', 'tokenize_final_article', 'stopwords_clean_final_article'], axis = 1, inplace = True)

# %%
df['lemmatized_clean_final_article'].apply(len).mean()
# Out:
# 260.2153607791058

# %%
df.head()
# Out:
#                                          articleBody  \
# 0  A small meteorite crashed into a wooded area i...
# 1  There is so much fake stuff on the Internet in...
# 2  (CNN) -- A meteorite crashed down in Managua, ...
# 3  (CNN) -- A meteorite crashed down in Managua, ...
# 4  A SOLDIER has been shot at Canada’s National W...
#
#                                             Headline  labels  \
# 0  Small Meteorite Strikes in Nicaragua's Capital...       1
# 1  What was fake on the Internet this week: Obama...       1
# 2  Meteorite makes big crater in Nicaragua, gover...       1
# 3  Small Meteorite Strikes in Nicaragua's Capital...       1
# 4  A soldier has been shot at Canada’s war memori...       1
#
#                                        final_article  \
# 0  small meteorite strikes in nicaragua's capital...
# 1  what was fake on the internet this week: obama...
# 2  meteorite makes big crater in nicaragua, gover...
# 3  small meteorite strikes in nicaragua's capital...
# 4  a soldier has been shot at canada’s war memori...
#
#                                  clean_final_article  \
# 0  small meteorite strikes in nicaragua's capital...
# 1  what was fake on the internet this week: obama...
# 2  meteorite makes big crater in nicaragua, gover...
# 3  small meteorite strikes in nicaragua's capital...
# 4  a soldier has been shot at canada’s war memori...
#
#                       lemmatized_clean_final_article
# 0  [small, meteorite, strike, nicaragua, 's, capi...
# 1  [fake, internet, week, :, obama, ’, peace, pri...
# 2  [meteorite, make, big, crater, nicaragua, ,, g...
# 3  [small, meteorite, strike, nicaragua, 's, capi...
# 4  [soldier, shot, canada, ’, war, memorial, step...

# %%
dir = os.getcwd()
change_dir = os.path.dirname(dir)
subdir = "Preprocessed_Dataset"

# %%
dir_path = os.path.join(change_dir, subdir)
print(dir_path)
# Out:
# C:\Users\cobra\project\project\Data_Preprocessing\Preprocessed_Dataset

# %%
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
    print(f"Created directory {dir_path}")
else:
    print(f"Directory {dir_path} already exists")
# Out:
# Directory C:\Users\cobra\project\project\Data_Preprocessing\Preprocessed_Dataset already exists

# %%
os.getcwd()
# Out:
# 'C:\\Users\\cobra\\project\\project\\Data_Preprocessing\\fnc1_Dataset'

# %%
df.to_csv('../Preprocessed_Dataset/fnc1_Preprocessed_Data.csv')
